# %%
import pandas as pd
import numpy as np
from pathlib import Path
import logging
import sys

# Clear any existing handlers to prevent duplicates
root_logger = logging.getLogger()
if root_logger.handlers:
    for handler in root_logger.handlers:
        root_logger.removeHandler(handler)

# Configure logging FIRST before importing DataLoader
logging.basicConfig(level=logging.WARNING, force=True)

# Suppress specific loggers that are verbose
for logger_name in ['__main__', 'snowflake', 'azure', 'urllib3']:
    logging.getLogger(logger_name).setLevel(logging.WARNING)

# Add the project root to the path to import custom modules
project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))

# Import the DataLoader class
from scripts.data_preparation.load import DataLoader

print("✓ Libraries imported successfully")
print("✓ Logging configured (INFO messages suppressed)")
# Out:
# ✓ Libraries imported successfully
# ✓ Logging configured (INFO messages suppressed)

# %%
# Getting email data from startdate to enddate
startdate = '2026-01-01'
enddate = '2026-05-11'

print(f"Tracking Email History will be Retrieved from {startdate} to {enddate}")
# Out:
# Tracking Email History will be Retrieved from 2026-01-01 to 2026-05-11

# %% [markdown]
# ## 1. Load Tracking Email Data from Snowflake
#
# Load the tracking email data from Snowflake using the DataLoader class.

# %%
# Execute the query to get historical load data
print("Querying Snowflake for Tracking Email data...")
print(f"Date Range: {startdate} to {enddate}")

loader = DataLoader()

df = loader.load_from_snowflake(
    sql_file_path='../sql/EmailExtractionToContextBuilder.sql',
    params={'startdate': startdate, 'enddate': enddate}
)

print(f"\n✓ Loaded {len(df):,} rows from Snowflake")
print(f"  Date range in data: {df['SENT_DATE'].min()} to {df['SENT_DATE'].max()}")
print(f"  Columns: {len(df.columns)}")
df.head()
# Out:
# Querying Snowflake for Tracking Email data...
# Date Range: 2026-01-01 to 2026-05-11
# /home/azureuser/trackingContextBuilder/trackingContextBuilder/scripts/data_preparation/load.py:160: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, self.snowflake_conn)
# ✓ Loaded 494,317 rows from Snowflake
#   Date range in data: 2026-01-02 to 2026-05-11
#   Columns: 19
#                                      CONVERSATION_ID  \
# 0  AAQkAGI1ZTM2ODMxLWI1NmYtNGM5OC05NjY1LTdhMDk2MW...
# 1  AAQkADI3YTc5NjQyLTI5OWQtNGI1ZC1hN2UzLThjZmNjNW...
# 2  AAQkADRmOGE2NjQyLWVjYmMtNGE0Ni1hOWEzLTIwMTQwYT...
# 3  AAQkAGMyNmY1NGI1LTdmOGItNDRjZC1iOWRjLTkzYzkzND...
# 4  AAQkADIzY2I2OTA3LWUzMGQtNDE0My05NjI3LTRjZjY5MW...
#
#                              MESSAGE_ID  \
# 0  5128cfe2-05a8-4344-84b6-68cd25d8b20d
# 1  3674a835-f09b-4cdd-876a-a180e3282fac
# 2  0db9b2ce-4f41-41ab-8743-c3e521f917ae
# 3  b5a4ed8e-82a0-428b-83df-ec9486d286f6
# 4  d0977b7b-c7d4-465c-baad-49dec9164fac
#
#                                              SUBJECT  \
# 0    回复： Re: 回复： Re: 回复： Re: 回复： 547005356 need ETa
# 1  RE: GKDRALA260763 RE: [INTERNAL]:RE: NEED BOL ...
# 2                             CH ROBINSON WEST 02-19
# 3                           Re: Driver ETA 244723172
# 4                                RE: IMDL Loads 2/27
#
#                                           EMAIL_TEXT  \
# 0  <html><head>\r\n<meta http-equiv="Content-Type...
# 1  <html><head>\r\n<meta http-equiv="Content-Type...
# 2  <html><head>\r\n<meta http-equiv="Content-Type...
# 3  <html><head>\r\n<meta http-equiv="Content-Type...
# 4  <html><head>\r\n<meta http-equiv="Content-Type...
#
#                            SENDER  SENDER_DOMAIN  SENDER_IS_CHR  \
# 0           pallogistic@yahoo.com      yahoo.com              0
# 1          jessica.wrobel@gxo.com        gxo.com              0
# 2           Ana.RLopez@ravago.com     ravago.com              0
# 3  Laura.Hernandez2@us.yazaki.com  us.yazaki.com              0
# 4      victoria.gatbunton@aldi.us        aldi.us              0
#
#                                            RECIPIENT  \
# 0           [\n  "Meliza.Baltazar@chrobinson.com"\n]
# 1  [\n  "Road.Driveline@gknautomotive.com",\n  "s...
# 2  [\n  "chr-ravago@chrobinson.com",\n  "CHR-FL@c...
# 3  [\n  "Cinthya.Montes@brose.com",\n  "Deanna.Ho...
# 4  [\n  "intltmplanning@aldi.us",\n  "mike.fikis@...
#
#                                     RECIPIENT_DOMAIN RECIPIENT_IS_CHR  \
# 0                           [\n  "chrobinson.com"\n]        [\n  1\n]
# 1  [\n  "gknautomotive.com",\n  "gxo.com",\n  "ch...  [\n  1,\n  0\n]
# 2                           [\n  "chrobinson.com"\n]        [\n  1\n]
# 3  [\n  "brose.com",\n  "chrobinson.com",\n  "us....  [\n  0,\n  1\n]
# 4             [\n  "aldi.us",\n  "chrobinson.com"\n]  [\n  1,\n  0\n]
#
#                TIME_SENT_UTC   SENT_DATE  SENT_HOUR   TIME_RECEIVED_UTC  \
# 0 2026-03-19 20:22:18.314046  2026-03-19         20 2026-03-19 20:22:17
# 1 2026-03-24 13:29:37.626560  2026-03-24         13 2026-03-24 13:29:34
# 2 2026-02-19 13:57:42.967921  2026-02-19         13 2026-02-19 13:57:42
# 3 2026-03-28 02:33:26.254735  2026-03-28          2 2026-03-28 02:33:25
# 4 2026-03-02 14:39:18.356985  2026-03-02         14 2026-03-02 14:39:18
#
#                                            MAILBOXES    CLASSIFICATION  \
# 0  [\n  {\n    "EmailId": "AAkALgAAAAAAHYQDEapmEc...  tracking-request
# 1  [\n  {\n    "EmailId": "AAkALgAAAAAAHYQDEapmEc...  tracking-request
# 2  [\n  {\n    "EmailId": "AAkALgAAAAAAHYQDEapmEc...  tracking-request
# 3  [\n  {\n    "EmailId": "",\n    "MailboxId": "...  tracking-request
# 4  [\n  {\n    "EmailId": "",\n    "MailboxId": "...  tracking-request
#
#   CATEGORIES MONTHSTARTDATE  WORKDAYS
# 0         []     2026-03-01        22
# 1         []     2026-03-01        22
# 2         []     2026-02-01        20
# 3         []     2026-03-01        22
# 4         []     2026-03-01        22

# %%
# Creating UDF to remove \n from dictionary columns
def remove_characters(col: str | None) -> str:
    """Remove newline characters from string values.
    
    Args:
        col: Input string value

    Returns:
        String with newline characters removed
    """
    if col is None or pd.isna(col):
        return ''
    return str(col).replace('\n','')

# %%
object_cols = df.select_dtypes(include=['object']).columns.tolist()
print(f"Found {len(object_cols)} object columns to process")
# Out:
# Found 14 object columns to process

# %%
object_cols = df.select_dtypes(include=['object']).columns.tolist()
print(f"Found {len(object_cols)} object columns to process")
# Out:
# Found 14 object columns to process

# %%
# OPTIMIZED VERSION: Use vectorized string operations instead of apply()
# This is 10-50x faster and uses less memory

import gc

print("🚀 Removing newline characters from object columns...")
print(f"Processing {len(object_cols)} columns")
print("="*80)

for i, col in enumerate(object_cols, 1):
    print(f"  [{i}/{len(object_cols)}] Processing: {col}")
    
    # Use vectorized string operations - much faster than apply()
    # fillna('') handles None/NaN values, str.replace does the work
    df[col] = df[col].fillna('').astype(str).str.replace('\n', '', regex=False)
    
    # Free up memory every few columns
    if i % 5 == 0:
        gc.collect()

print("="*80)
print("✅ All columns processed successfully!")
print(f"Memory freed: {gc.collect()} objects")
# Out:
# 🚀 Removing newline characters from object columns...
# Processing 14 columns
# ================================================================================
#   [1/14] Processing: CONVERSATION_ID
#   [2/14] Processing: MESSAGE_ID
#   [3/14] Processing: SUBJECT
#   [3/14] Processing: SUBJECT
#   [4/14] Processing: EMAIL_TEXT
#   [4/14] Processing: EMAIL_TEXT
#   [5/14] Processing: SENDER
#   [5/14] Processing: SENDER
#   [6/14] Processing: SENDER_DOMAIN
#   [7/14] Processing: RECIPIENT
#   [6/14] Processing: SENDER_DOMAIN
#   [7/14] Processing: RECIPIENT
#   [8/14] Processing: RECIPIENT_DOMAIN
#   [8/14] Processing: RECIPIENT_DOMAIN
#   [9/14] Processing: RECIPIENT_IS_CHR
#   [10/14] Processing: SENT_DATE
#   [9/14] Processing: RECIPIENT_IS_CHR
#   [10/14] Processing: SENT_DATE
#   [11/14] Processing: MAILBOXES
#   [11/14] Processing: MAILBOXES
#   [12/14] Processing: CLASSIFICATION
#   [13/14] Processing: CATEGORIES
#   [12/14] Processing: CLASSIFICATION
#   [13/14] Processing: CATEGORIES
#   [14/14] Processing: MONTHSTARTDATE
#   [14/14] Processing: MONTHSTARTDATE
# ================================================================================
# ✅ All columns processed successfully!
# Memory freed: 76 objects
# ================================================================================
# ✅ All columns processed successfully!
# Memory freed: 76 objects

# %% [markdown]
# ### Clean HTML from Email Text
#
# Remove HTML tags and extract human-readable content from email bodies.

# %%
from bs4 import BeautifulSoup
import re

def clean_email_html(html_text: str | None) -> str:
    """
    Extract clean, human-readable text from HTML email content.
    
    Removes:
    - All HTML tags
    - Script and style elements
    - Excessive whitespace and newlines
    - Email headers (From:, To:, Sent:, etc.)
    - Common email signatures and disclaimers
    
    Args:
        html_text: Raw HTML email content
        
    Returns:
        Clean, human-readable text content
    """
    if pd.isna(html_text) or html_text == '':
        return ''
    
    try:
        # Parse HTML with BeautifulSoup
        soup = BeautifulSoup(str(html_text), 'html.parser')
        
        # Remove script, style, and meta tags (non-content elements)
        for element in soup(['script', 'style', 'meta', 'link', 'head']):
            element.decompose()
        
        # Get text content
        text = soup.get_text(separator=' ', strip=True)
        
        # Clean up common email artifacts
        # Remove email headers (From:, To:, Sent:, Subject:, etc.)
        text = re.sub(r'^(From|To|Sent|Date|Subject|Cc|Bcc):\s*.*?$', '', text, flags=re.MULTILINE | re.IGNORECASE)
        
        # Remove common disclaimer patterns
        disclaimer_patterns = [
            r'This email.*?confidential.*?intended recipient.*?[\r\n]+',
            r'CONFIDENTIALITY NOTICE:.*?[\r\n]+',
            r'This message.*?confidential.*?[\r\n]+',
            r'If you are not the intended recipient.*?[\r\n]+',
            r'Please consider the environment before printing this email.*?[\r\n]+',
        ]
        for pattern in disclaimer_patterns:
            text = re.sub(pattern, '', text, flags=re.IGNORECASE | re.DOTALL)
        
        # Remove excessive whitespace
        text = re.sub(r'\s+', ' ', text)  # Multiple spaces to single space
        text = re.sub(r'\n\s*\n+', '\n\n', text)  # Multiple newlines to double newline
        
        # Remove leading/trailing whitespace
        text = text.strip()
        
        return text
    
    except Exception as e:
        # If parsing fails, return original text with minimal cleaning
        print(f"Warning: HTML parsing failed, returning minimally cleaned text. Error: {e}")
        # At minimum, remove HTML tags with regex
        text = re.sub(r'<[^>]+>', ' ', str(html_text))
        text = re.sub(r'\s+', ' ', text)
        return text.strip()

print("✅ HTML cleaning function created: clean_email_html()")
# Out:
# ✅ HTML cleaning function created: clean_email_html()

# %% [markdown]
# ### Optimized HTML Cleaning (Faster Single-Process Version)
#
# A faster version that uses lxml directly and vectorized operations.

# %%
import re
from bs4 import BeautifulSoup

# Pre-compile regex patterns for better performance
HEADER_PATTERN = re.compile(r'^(From|To|Sent|Date|Subject|Cc|Bcc):\s*.*?$', re.MULTILINE | re.IGNORECASE)
DISCLAIMER_PATTERNS = [
    re.compile(r'This email.*?confidential.*?intended recipient.*?[\r\n]+', re.IGNORECASE | re.DOTALL),
    re.compile(r'CONFIDENTIALITY NOTICE:.*?[\r\n]+', re.IGNORECASE | re.DOTALL),
    re.compile(r'This message.*?confidential.*?[\r\n]+', re.IGNORECASE | re.DOTALL),
    re.compile(r'If you are not the intended recipient.*?[\r\n]+', re.IGNORECASE | re.DOTALL),
    re.compile(r'Please consider the environment before printing this email.*?[\r\n]+', re.IGNORECASE | re.DOTALL),
]
WHITESPACE_PATTERN = re.compile(r'\s+')
NEWLINE_PATTERN = re.compile(r'\n\s*\n+')
HTML_TAG_PATTERN = re.compile(r'<[^>]+>')

def clean_email_html_optimized(html_text: str | None) -> str:
    """
    Optimized version of clean_email_html with pre-compiled regex patterns.
    
    Args:
        html_text: Raw HTML email content
        
    Returns:
        Clean, human-readable text content
    """
    if pd.isna(html_text) or html_text == '':
        return ''
    
    try:
        # Parse HTML with BeautifulSoup (lxml parser is fastest)
        soup = BeautifulSoup(str(html_text), 'lxml')
        
        # Remove non-content elements
        for element in soup(['script', 'style', 'meta', 'link', 'head']):
            element.decompose()
        
        # Get text content
        text = soup.get_text(separator=' ', strip=True)
        
        # Remove email headers
        text = HEADER_PATTERN.sub('', text)
        
        # Remove disclaimers
        for pattern in DISCLAIMER_PATTERNS:
            text = pattern.sub('', text)
        
        # Clean whitespace
        text = WHITESPACE_PATTERN.sub(' ', text)
        text = NEWLINE_PATTERN.sub('\n\n', text)
        
        return text.strip()
    
    except Exception:
        # Fallback: minimal cleaning with regex
        text = HTML_TAG_PATTERN.sub(' ', str(html_text))
        text = WHITESPACE_PATTERN.sub(' ', text)
        return text.strip()

print("✅ Optimized cleaning function created: clean_email_html_optimized()")
print("   - Uses pre-compiled regex patterns for ~2-3x speed improvement")
print("   - Faster lxml parser")
# Out:
# ✅ Optimized cleaning function created: clean_email_html_optimized()
#    - Uses pre-compiled regex patterns for ~2-3x speed improvement
#    - Faster lxml parser

# %% [markdown]
# ### Apply Optimized Cleaning (Choose ONE option below)
#
# **Option 1**: Use optimized single-process version (recommended for <50k emails)
# **Option 2**: Use parallel processing version (recommended for 50k+ emails)

# %% [markdown]
# ### Parallel HTML Cleaning Function (Optional)
#
# Only needed if you want to use parallel processing for very large datasets (50k+ emails).

# %%
from multiprocessing import Pool, cpu_count
import time

def clean_email_batch(batch_data):
    """
    Clean a batch of emails (for parallel processing).
    
    Args:
        batch_data: Tuple of (batch_index, email_texts_list)
        
    Returns:
        Tuple of (batch_index, cleaned_texts_list)
    """
    batch_idx, emails = batch_data
    cleaned = [clean_email_html_optimized(email) for email in emails]
    return batch_idx, cleaned


def parallel_clean_emails(df, column_name='EMAIL_TEXT', num_workers=None, chunk_size=1000):
    """
    Clean HTML from emails using parallel processing.
    
    Args:
        df: DataFrame with email data
        column_name: Name of column containing HTML email text
        num_workers: Number of parallel workers (default: CPU count - 1)
        chunk_size: Number of emails per batch
        
    Returns:
        List of cleaned email texts in same order as input
    """
    if column_name not in df.columns:
        print(f"⚠️ Column '{column_name}' not found in dataframe")
        return []
    
    # Set number of workers
    if num_workers is None:
        num_workers = max(1, cpu_count() - 1)  # Leave one core free
    
    total_emails = len(df)
    print(f"\n{'='*80}")
    print(f"🚀 PARALLEL HTML CLEANING")
    print(f"{'='*80}")
    print(f"Total emails: {total_emails:,}")
    print(f"Workers: {num_workers}")
    print(f"Chunk size: {chunk_size:,}")
    print(f"Total chunks: {(total_emails + chunk_size - 1) // chunk_size}")
    print(f"{'='*80}\n")
    
    # Split data into chunks
    email_series = df[column_name]
    chunks = []
    for i in range(0, total_emails, chunk_size):
        chunk = email_series.iloc[i:i+chunk_size].tolist()
        chunks.append((i // chunk_size, chunk))
    
    print(f"Starting parallel processing...")
    start_time = time.time()
    
    # Process chunks in parallel
    with Pool(processes=num_workers) as pool:
        results = pool.map(clean_email_batch, chunks)
    
    end_time = time.time()
    elapsed_time = end_time - start_time
    
    # Sort results by batch index and flatten
    results.sort(key=lambda x: x[0])
    cleaned_emails = []
    for _, batch_cleaned in results:
        cleaned_emails.extend(batch_cleaned)
    
    print(f"\n✅ Parallel processing complete!")
    print(f"{'='*80}")
    print(f"⏱️  Total time: {elapsed_time:.1f} seconds ({elapsed_time/60:.1f} minutes)")
    print(f"   Average: {elapsed_time/total_emails*1000:.2f} ms per email")
    print(f"   Throughput: {total_emails/elapsed_time:.0f} emails/second")
    print(f"{'='*80}\n")
    
    return cleaned_emails

print("✅ Parallel cleaning function created: parallel_clean_emails()")
print("   Note: Uses clean_email_html_optimized() internally")
# Out:
# ✅ Parallel cleaning function created: parallel_clean_emails()
#    Note: Uses clean_email_html_optimized() internally

# %%
# # OPTION 1: Optimized Single-Process Version (2-3x faster than original)
# # Best for: 34k emails or less, simpler to use

# import time

# if 'EMAIL_TEXT' in df.columns:
#     print(f"🚀 Applying optimized HTML cleaning to {len(df):,} emails...")
#     print("="*80)
    
#     start_time = time.time()
#     df['EMAIL_TEXT_CLEAN'] = df['EMAIL_TEXT'].apply(clean_email_html_optimized)
#     end_time = time.time()
    
#     elapsed_time = end_time - start_time
    
#     print(f"\n✅ Optimized HTML cleaning complete!")
#     print(f"⏱️  Total time: {elapsed_time:.1f} seconds ({elapsed_time/60:.1f} minutes)")
#     print(f"   Average: {elapsed_time/len(df)*1000:.2f} ms per email")
#     print(f"   Throughput: {len(df)/elapsed_time:.0f} emails/second")
    
#     # Show before/after example
#     print(f"\n{'='*80}")
#     print(f"Example comparison (first email with content):")
#     print("="*80)
    
#     for idx in range(min(5, len(df))):
#         if pd.notna(df['EMAIL_TEXT'].iloc[idx]) and len(str(df['EMAIL_TEXT'].iloc[idx])) > 100:
#             print(f"\nORIGINAL (first 500 chars):")
#             print("-"*80)
#             print(str(df['EMAIL_TEXT'].iloc[idx])[:500])
#             print("\n" + "="*80)
#             print(f"\nCLEANED:")
#             print("-"*80)
#             print(str(df['EMAIL_TEXT_CLEAN'].iloc[idx])[:500])
#             print("\n" + "="*80)
#             break
    
#     # Statistics
#     avg_original_length = df['EMAIL_TEXT'].apply(lambda x: len(str(x)) if pd.notna(x) else 0).mean()
#     avg_clean_length = df['EMAIL_TEXT_CLEAN'].apply(lambda x: len(str(x)) if pd.notna(x) else 0).mean()
#     reduction_pct = ((avg_original_length - avg_clean_length) / avg_original_length * 100) if avg_original_length > 0 else 0
    
#     print(f"\n📊 Cleaning Statistics:")
#     print(f"  Average original length: {avg_original_length:,.0f} characters")
#     print(f"  Average cleaned length: {avg_clean_length:,.0f} characters")
#     print(f"  Size reduction: {reduction_pct:.1f}%")
#     print("="*80)
# else:
#     print("⚠️  EMAIL_TEXT column not found in dataframe")

# %%
# # OPTION 2: Parallel Processing Version (4-8x faster than original)
# # Best for: 50k+ emails, will use all available CPU cores
# # NOTE: Skip this cell if you already ran Option 1 above!

# if 'EMAIL_TEXT' in df.columns:
#     # Use parallel processing with reduced workers to prevent memory crashes
#     # IMPORTANT: Reduce num_workers if you experience kernel crashes
#     cleaned_emails = parallel_clean_emails(
#         df=df,
#         column_name='EMAIL_TEXT',
#         num_workers=2,     # REDUCED: Use 2-4 workers instead of all cores to prevent crashes
#         chunk_size=500     # REDUCED: Smaller chunks to reduce memory per worker
#     )
    
#     # Add cleaned emails to dataframe
#     df['EMAIL_TEXT_CLEAN'] = cleaned_emails
    
#     # Show before/after example
#     print(f"\nExample comparison (first email with content):")
#     print("="*80)
    
#     for idx in range(min(5, len(df))):
#         if pd.notna(df['EMAIL_TEXT'].iloc[idx]) and len(str(df['EMAIL_TEXT'].iloc[idx])) > 100:
#             print(f"\nORIGINAL (first 500 chars):")
#             print("-"*80)
#             print(str(df['EMAIL_TEXT'].iloc[idx])[:500])
#             print("\n" + "="*80)
#             print(f"\nCLEANED:")
#             print("-"*80)
#             print(str(df['EMAIL_TEXT_CLEAN'].iloc[idx])[:500])
#             print("\n" + "="*80)
#             break
    
#     # Statistics
#     avg_original_length = df['EMAIL_TEXT'].apply(lambda x: len(str(x)) if pd.notna(x) else 0).mean()
#     avg_clean_length = df['EMAIL_TEXT_CLEAN'].apply(lambda x: len(str(x)) if pd.notna(x) else 0).mean()
#     reduction_pct = ((avg_original_length - avg_clean_length) / avg_original_length * 100) if avg_original_length > 0 else 0
    
#     print(f"\n📊 Cleaning Statistics:")
#     print(f"  Average original length: {avg_original_length:,.0f} characters")
#     print(f"  Average cleaned length: {avg_clean_length:,.0f} characters")
#     print(f"  Size reduction: {reduction_pct:.1f}%")
# else:
#     print("⚠️  EMAIL_TEXT column not found in dataframe")

# %%
# OPTION 3: Safer Batch Parallel Processing (Prevents Kernel Crashes)
# This processes the dataframe in large batches to avoid memory overload

if 'EMAIL_TEXT' in df.columns:
    import gc
    import time
    
    # Configuration
    batch_size = 20000  # Process 20k emails at a time
    num_workers = 2     # Limited workers to prevent memory crash
    chunk_size = 500    # Smaller chunks per worker
    
    total_emails = len(df)
    num_batches = (total_emails + batch_size - 1) // batch_size
    
    print(f"🚀 SAFE BATCH PARALLEL PROCESSING")
    print(f"="*80)
    print(f"Total emails: {total_emails:,}")
    print(f"Batch size: {batch_size:,}")
    print(f"Number of batches: {num_batches}")
    print(f"Workers per batch: {num_workers}")
    print(f"="*80 + "\n")
    
    all_cleaned = []
    overall_start = time.time()
    
    for batch_num in range(num_batches):
        start_idx = batch_num * batch_size
        end_idx = min((batch_num + 1) * batch_size, total_emails)
        
        print(f"📧 Batch {batch_num + 1}/{num_batches}: Processing rows {start_idx:,} to {end_idx:,}...")
        
        # Extract batch
        batch_df = df.iloc[start_idx:end_idx].copy()
        
        # Process batch in parallel
        batch_cleaned = parallel_clean_emails(
            df=batch_df,
            column_name='EMAIL_TEXT',
            num_workers=num_workers,
            chunk_size=chunk_size
        )
        
        # Collect results
        all_cleaned.extend(batch_cleaned)
        
        # Clean up memory
        del batch_df
        del batch_cleaned
        gc.collect()
        
        print(f"✓ Batch {batch_num + 1} complete. Progress: {len(all_cleaned):,}/{total_emails:,}\n")
    
    # Add cleaned emails to dataframe
    df['EMAIL_TEXT_CLEAN'] = all_cleaned
    
    overall_time = time.time() - overall_start
    
    print(f"\n{'='*80}")
    print(f"✅ ALL BATCHES COMPLETE!")
    print(f"Total time: {overall_time:.1f} seconds ({overall_time/60:.1f} minutes)")
    print(f"Average: {overall_time/total_emails*1000:.2f} ms per email")
    print(f"{'='*80}")
    
    # Show statistics
    avg_original_length = df['EMAIL_TEXT'].apply(lambda x: len(str(x)) if pd.notna(x) else 0).mean()
    avg_clean_length = df['EMAIL_TEXT_CLEAN'].apply(lambda x: len(str(x)) if pd.notna(x) else 0).mean()
    reduction_pct = ((avg_original_length - avg_clean_length) / avg_original_length * 100) if avg_original_length > 0 else 0
    
    print(f"\n📊 Cleaning Statistics:")
    print(f"  Average original length: {avg_original_length:,.0f} characters")
    print(f"  Average cleaned length: {avg_clean_length:,.0f} characters")
    print(f"  Size reduction: {reduction_pct:.1f}%")
else:
    print("⚠️  EMAIL_TEXT column not found in dataframe")
# Out:
# 🚀 SAFE BATCH PARALLEL PROCESSING
# ================================================================================
# Total emails: 494,317
# Batch size: 20,000
# Number of batches: 25
# Workers per batch: 2
# ================================================================================
#
# 📧 Batch 1/25: Processing rows 0 to 20,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 12.0 seconds (0.2 minutes)
#    Average: 0.60 ms per email
#    Throughput: 1661 emails/second
# ================================================================================
#
# ✓ Batch 1 complete. Progress: 20,000/494,317
#
# 📧 Batch 2/25: Processing rows 20,000 to 40,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 12.4 seconds (0.2 minutes)
#    Average: 0.62 ms per email
#    Throughput: 1617 emails/second
# ================================================================================
#
# ✓ Batch 2 complete. Progress: 40,000/494,317
#
# 📧 Batch 3/25: Processing rows 40,000 to 60,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 12.4 seconds (0.2 minutes)
#    Average: 0.62 ms per email
#    Throughput: 1617 emails/second
# ================================================================================
#
# ✓ Batch 2 complete. Progress: 40,000/494,317
#
# 📧 Batch 3/25: Processing rows 40,000 to 60,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 12.3 seconds (0.2 minutes)
#    Average: 0.62 ms per email
#    Throughput: 1625 emails/second
# ================================================================================
#
# ✓ Batch 3 complete. Progress: 60,000/494,317
#
# 📧 Batch 4/25: Processing rows 60,000 to 80,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 12.3 seconds (0.2 minutes)
#    Average: 0.62 ms per email
#    Throughput: 1625 emails/second
# ================================================================================
#
# ✓ Batch 3 complete. Progress: 60,000/494,317
#
# 📧 Batch 4/25: Processing rows 60,000 to 80,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 12.4 seconds (0.2 minutes)
#    Average: 0.62 ms per email
#    Throughput: 1611 emails/second
# ================================================================================
#
# ✓ Batch 4 complete. Progress: 80,000/494,317
#
# 📧 Batch 5/25: Processing rows 80,000 to 100,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 12.4 seconds (0.2 minutes)
#    Average: 0.62 ms per email
#    Throughput: 1611 emails/second
# ================================================================================
#
# ✓ Batch 4 complete. Progress: 80,000/494,317
#
# 📧 Batch 5/25: Processing rows 80,000 to 100,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 12.4 seconds (0.2 minutes)
#    Average: 0.62 ms per email
#    Throughput: 1619 emails/second
# ================================================================================
#
# ✓ Batch 5 complete. Progress: 100,000/494,317
#
# 📧 Batch 6/25: Processing rows 100,000 to 120,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 12.4 seconds (0.2 minutes)
#    Average: 0.62 ms per email
#    Throughput: 1619 emails/second
# ================================================================================
#
# ✓ Batch 5 complete. Progress: 100,000/494,317
#
# 📧 Batch 6/25: Processing rows 100,000 to 120,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 12.8 seconds (0.2 minutes)
#    Average: 0.64 ms per email
#    Throughput: 1564 emails/second
# ================================================================================
#
# ✓ Batch 6 complete. Progress: 120,000/494,317
#
# 📧 Batch 7/25: Processing rows 120,000 to 140,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 12.8 seconds (0.2 minutes)
#    Average: 0.64 ms per email
#    Throughput: 1564 emails/second
# ================================================================================
#
# ✓ Batch 6 complete. Progress: 120,000/494,317
#
# 📧 Batch 7/25: Processing rows 120,000 to 140,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 12.5 seconds (0.2 minutes)
#    Average: 0.62 ms per email
#    Throughput: 1602 emails/second
# ================================================================================
#
# ✓ Batch 7 complete. Progress: 140,000/494,317
#
# 📧 Batch 8/25: Processing rows 140,000 to 160,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 12.5 seconds (0.2 minutes)
#    Average: 0.62 ms per email
#    Throughput: 1602 emails/second
# ================================================================================
#
# ✓ Batch 7 complete. Progress: 140,000/494,317
#
# 📧 Batch 8/25: Processing rows 140,000 to 160,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 12.7 seconds (0.2 minutes)
#    Average: 0.63 ms per email
#    Throughput: 1580 emails/second
# ================================================================================
#
# ✓ Batch 8 complete. Progress: 160,000/494,317
#
# 📧 Batch 9/25: Processing rows 160,000 to 180,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 12.7 seconds (0.2 minutes)
#    Average: 0.63 ms per email
#    Throughput: 1580 emails/second
# ================================================================================
#
# ✓ Batch 8 complete. Progress: 160,000/494,317
#
# 📧 Batch 9/25: Processing rows 160,000 to 180,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 13.1 seconds (0.2 minutes)
#    Average: 0.65 ms per email
#    Throughput: 1529 emails/second
# ================================================================================
#
# ✓ Batch 9 complete. Progress: 180,000/494,317
#
# 📧 Batch 10/25: Processing rows 180,000 to 200,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 13.1 seconds (0.2 minutes)
#    Average: 0.65 ms per email
#    Throughput: 1529 emails/second
# ================================================================================
#
# ✓ Batch 9 complete. Progress: 180,000/494,317
#
# 📧 Batch 10/25: Processing rows 180,000 to 200,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 13.5 seconds (0.2 minutes)
#    Average: 0.68 ms per email
#    Throughput: 1481 emails/second
# ================================================================================
#
# ✓ Batch 10 complete. Progress: 200,000/494,317
#
# 📧 Batch 11/25: Processing rows 200,000 to 220,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 13.5 seconds (0.2 minutes)
#    Average: 0.68 ms per email
#    Throughput: 1481 emails/second
# ================================================================================
#
# ✓ Batch 10 complete. Progress: 200,000/494,317
#
# 📧 Batch 11/25: Processing rows 200,000 to 220,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 13.0 seconds (0.2 minutes)
#    Average: 0.65 ms per email
#    Throughput: 1533 emails/second
# ================================================================================
#
# ✓ Batch 11 complete. Progress: 220,000/494,317
#
# 📧 Batch 12/25: Processing rows 220,000 to 240,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 13.0 seconds (0.2 minutes)
#    Average: 0.65 ms per email
#    Throughput: 1533 emails/second
# ================================================================================
#
# ✓ Batch 11 complete. Progress: 220,000/494,317
#
# 📧 Batch 12/25: Processing rows 220,000 to 240,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 13.2 seconds (0.2 minutes)
#    Average: 0.66 ms per email
#    Throughput: 1514 emails/second
# ================================================================================
#
# ✓ Batch 12 complete. Progress: 240,000/494,317
#
# 📧 Batch 13/25: Processing rows 240,000 to 260,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 13.2 seconds (0.2 minutes)
#    Average: 0.66 ms per email
#    Throughput: 1514 emails/second
# ================================================================================
#
# ✓ Batch 12 complete. Progress: 240,000/494,317
#
# 📧 Batch 13/25: Processing rows 240,000 to 260,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 13.4 seconds (0.2 minutes)
#    Average: 0.67 ms per email
#    Throughput: 1491 emails/second
# ================================================================================
#
# ✓ Batch 13 complete. Progress: 260,000/494,317
#
# 📧 Batch 14/25: Processing rows 260,000 to 280,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 13.4 seconds (0.2 minutes)
#    Average: 0.67 ms per email
#    Throughput: 1491 emails/second
# ================================================================================
#
# ✓ Batch 13 complete. Progress: 260,000/494,317
#
# 📧 Batch 14/25: Processing rows 260,000 to 280,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 13.3 seconds (0.2 minutes)
#    Average: 0.67 ms per email
#    Throughput: 1500 emails/second
# ================================================================================
#
# ✓ Batch 14 complete. Progress: 280,000/494,317
#
# 📧 Batch 15/25: Processing rows 280,000 to 300,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 13.3 seconds (0.2 minutes)
#    Average: 0.67 ms per email
#    Throughput: 1500 emails/second
# ================================================================================
#
# ✓ Batch 14 complete. Progress: 280,000/494,317
#
# 📧 Batch 15/25: Processing rows 280,000 to 300,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 13.0 seconds (0.2 minutes)
#    Average: 0.65 ms per email
#    Throughput: 1537 emails/second
# ================================================================================
#
# ✓ Batch 15 complete. Progress: 300,000/494,317
#
# 📧 Batch 16/25: Processing rows 300,000 to 320,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 13.0 seconds (0.2 minutes)
#    Average: 0.65 ms per email
#    Throughput: 1537 emails/second
# ================================================================================
#
# ✓ Batch 15 complete. Progress: 300,000/494,317
#
# 📧 Batch 16/25: Processing rows 300,000 to 320,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 13.2 seconds (0.2 minutes)
#    Average: 0.66 ms per email
#    Throughput: 1513 emails/second
# ================================================================================
#
# ✓ Batch 16 complete. Progress: 320,000/494,317
#
# 📧 Batch 17/25: Processing rows 320,000 to 340,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 13.2 seconds (0.2 minutes)
#    Average: 0.66 ms per email
#    Throughput: 1513 emails/second
# ================================================================================
#
# ✓ Batch 16 complete. Progress: 320,000/494,317
#
# 📧 Batch 17/25: Processing rows 320,000 to 340,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 13.0 seconds (0.2 minutes)
#    Average: 0.65 ms per email
#    Throughput: 1544 emails/second
# ================================================================================
#
# ✓ Batch 17 complete. Progress: 340,000/494,317
#
# 📧 Batch 18/25: Processing rows 340,000 to 360,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 13.0 seconds (0.2 minutes)
#    Average: 0.65 ms per email
#    Throughput: 1544 emails/second
# ================================================================================
#
# ✓ Batch 17 complete. Progress: 340,000/494,317
#
# 📧 Batch 18/25: Processing rows 340,000 to 360,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 13.1 seconds (0.2 minutes)
#    Average: 0.66 ms per email
#    Throughput: 1522 emails/second
# ================================================================================
#
# ✓ Batch 18 complete. Progress: 360,000/494,317
#
# 📧 Batch 19/25: Processing rows 360,000 to 380,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 13.1 seconds (0.2 minutes)
#    Average: 0.66 ms per email
#    Throughput: 1522 emails/second
# ================================================================================
#
# ✓ Batch 18 complete. Progress: 360,000/494,317
#
# 📧 Batch 19/25: Processing rows 360,000 to 380,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 13.6 seconds (0.2 minutes)
#    Average: 0.68 ms per email
#    Throughput: 1467 emails/second
# ================================================================================
#
# ✓ Batch 19 complete. Progress: 380,000/494,317
#
# 📧 Batch 20/25: Processing rows 380,000 to 400,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 13.6 seconds (0.2 minutes)
#    Average: 0.68 ms per email
#    Throughput: 1467 emails/second
# ================================================================================
#
# ✓ Batch 19 complete. Progress: 380,000/494,317
#
# 📧 Batch 20/25: Processing rows 380,000 to 400,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 13.6 seconds (0.2 minutes)
#    Average: 0.68 ms per email
#    Throughput: 1475 emails/second
# ================================================================================
#
# ✓ Batch 20 complete. Progress: 400,000/494,317
#
# 📧 Batch 21/25: Processing rows 400,000 to 420,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 13.6 seconds (0.2 minutes)
#    Average: 0.68 ms per email
#    Throughput: 1475 emails/second
# ================================================================================
#
# ✓ Batch 20 complete. Progress: 400,000/494,317
#
# 📧 Batch 21/25: Processing rows 400,000 to 420,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 13.8 seconds (0.2 minutes)
#    Average: 0.69 ms per email
#    Throughput: 1453 emails/second
# ================================================================================
#
# ✓ Batch 21 complete. Progress: 420,000/494,317
#
# 📧 Batch 22/25: Processing rows 420,000 to 440,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 13.8 seconds (0.2 minutes)
#    Average: 0.69 ms per email
#    Throughput: 1453 emails/second
# ================================================================================
#
# ✓ Batch 21 complete. Progress: 420,000/494,317
#
# 📧 Batch 22/25: Processing rows 420,000 to 440,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 13.4 seconds (0.2 minutes)
#    Average: 0.67 ms per email
#    Throughput: 1490 emails/second
# ================================================================================
#
# ✓ Batch 22 complete. Progress: 440,000/494,317
#
# 📧 Batch 23/25: Processing rows 440,000 to 460,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 13.4 seconds (0.2 minutes)
#    Average: 0.67 ms per email
#    Throughput: 1490 emails/second
# ================================================================================
#
# ✓ Batch 22 complete. Progress: 440,000/494,317
#
# 📧 Batch 23/25: Processing rows 440,000 to 460,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 13.9 seconds (0.2 minutes)
#    Average: 0.70 ms per email
#    Throughput: 1435 emails/second
# ================================================================================
#
# ✓ Batch 23 complete. Progress: 460,000/494,317
#
# 📧 Batch 24/25: Processing rows 460,000 to 480,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 13.9 seconds (0.2 minutes)
#    Average: 0.70 ms per email
#    Throughput: 1435 emails/second
# ================================================================================
#
# ✓ Batch 23 complete. Progress: 460,000/494,317
#
# 📧 Batch 24/25: Processing rows 460,000 to 480,000...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 20,000
# Workers: 2
# Chunk size: 500
# Total chunks: 40
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 13.7 seconds (0.2 minutes)
#    Average: 0.68 ms per email
#    Throughput: 1460 emails/second
# ================================================================================
#
# ✓ Batch 24 complete. Progress: 480,000/494,317
#
# 📧 Batch 25/25: Processing rows 480,000 to 494,317...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 14,317
# Workers: 2
# Chunk size: 500
# Total chunks: 29
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 13.7 seconds (0.2 minutes)
#    Average: 0.68 ms per email
#    Throughput: 1460 emails/second
# ================================================================================
#
# ✓ Batch 24 complete. Progress: 480,000/494,317
#
# 📧 Batch 25/25: Processing rows 480,000 to 494,317...
#
# ================================================================================
# 🚀 PARALLEL HTML CLEANING
# ================================================================================
# Total emails: 14,317
# Workers: 2
# Chunk size: 500
# Total chunks: 29
# ================================================================================
#
# Starting parallel processing...
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 11.2 seconds (0.2 minutes)
#    Average: 0.78 ms per email
#    Throughput: 1276 emails/second
# ================================================================================
#
# ✓ Batch 25 complete. Progress: 494,317/494,317
#
#
# ✅ Parallel processing complete!
# ================================================================================
# ⏱️  Total time: 11.2 seconds (0.2 minutes)
#    Average: 0.78 ms per email
#    Throughput: 1276 emails/second
# ================================================================================
#
# ✓ Batch 25 complete. Progress: 494,317/494,317
#
#
# ================================================================================
# ✅ ALL BATCHES COMPLETE!
# Total time: 328.8 seconds (5.5 minutes)
# Average: 0.67 ms per email
# ================================================================================
#
# ================================================================================
# ✅ ALL BATCHES COMPLETE!
# Total time: 328.8 seconds (5.5 minutes)
# Average: 0.67 ms per email
# ================================================================================
#
# 📊 Cleaning Statistics:
#   Average original length: 65,585 characters
#   Average cleaned length: 10,282 characters
#   Size reduction: 84.3%
#
# 📊 Cleaning Statistics:
#   Average original length: 65,585 characters
#   Average cleaned length: 10,282 characters
#   Size reduction: 84.3%

# %%
# df.groupby('CONVERSATION_ID').agg({'MESSAGE_ID':'nunique'}).sort_values(by='MESSAGE_ID', ascending=False).head(25)

# %%
# tester = df[df['CONVERSATION_ID']=='AAQkADlmYWY5NDg3LThjNmItNDAyNi1hYjBkLTZjNWU1NDAxOTY1YwAQACDHs14MmXhPhHUIc8IMo4s='].sort_values(by='TIME_SENT_UTC')
# tester.to_csv('/home/azureuser/trackingContextBuilder/trackingContextBuilder/data/processed/tester_email_thread.csv', index=False)
# tester

# %% [markdown]
# ## 2. Load Tracking Identifier Crosswalk Data from Snowflake
#
# This will allow mapping of emails back to individual Ccodes

# %%
# Execute the query to get historical load data
print("Querying Snowflake for Tracking Identifier Crosswalk data...")
print(f"Date Range: {startdate} to {enddate}")

loader = DataLoader()

crosswalk_raw = loader.load_from_snowflake(
    sql_file_path='../sql/loadNumbertoReferenceNumMatching.sql',
    params={'startdate': startdate}
)

print(f"\n✓ Loaded {len(crosswalk_raw):,} rows from Snowflake")
print(f"  Original columns: {len(crosswalk_raw.columns)}")

# Restructure crosswalk to have one row per (loadnumber, partycode, carrier) combination
# Group by load/party/carrier and aggregate REFNUMs into arrays
print("\nRestructuring crosswalk: grouping by loadnumber, partycode, carrier...")
crosswalk_df = crosswalk_raw.groupby(
    ['LOADNUMBER', 'PARTYCODE', 'CARRIER_CODE', 'CARRIER_NAME'], 
    dropna=False
).agg({
    'REFNUM': lambda x: list(x.dropna().unique())  # Collect unique REFNUMs as array
}).reset_index()

# Rename the aggregated column for clarity
crosswalk_df.rename(columns={'REFNUM': 'REFNUMS'}, inplace=True)

print(f"✓ Crosswalk restructured!")
print(f"  Original rows: {len(crosswalk_raw):,}")
print(f"  Grouped rows: {len(crosswalk_df):,} (one per load/party/carrier)")
print(f"  Columns: {list(crosswalk_df.columns)}")

# Show example of REFNUMS array
print(f"\nExample REFNUMS array:")
if len(crosswalk_df) > 0:
    example_row = crosswalk_df.iloc[0]
    print(f"  Load: {example_row['LOADNUMBER']}")
    print(f"  REFNUMs: {example_row['REFNUMS'][:5]}..." if len(example_row['REFNUMS']) > 5 else f"  REFNUMs: {example_row['REFNUMS']}")

crosswalk_df.head()
# Out:
# Querying Snowflake for Tracking Identifier Crosswalk data...
# Date Range: 2026-01-01 to 2026-05-11
# /home/azureuser/trackingContextBuilder/trackingContextBuilder/scripts/data_preparation/load.py:160: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, self.snowflake_conn)
# ✓ Loaded 11,523,111 rows from Snowflake
#   Original columns: 5
#
# Restructuring crosswalk: grouping by loadnumber, partycode, carrier...
# ✓ Crosswalk restructured!
#   Original rows: 11,523,111
#   Grouped rows: 2,064,124 (one per load/party/carrier)
#   Columns: ['LOADNUMBER', 'PARTYCODE', 'CARRIER_CODE', 'CARRIER_NAME', 'REFNUMS']
#
# Example REFNUMS array:
#   Load: 512914816
#   REFNUMs: ['3500053163 – Monica Howe', '512914816', '1683011516']
# ✓ Crosswalk restructured!
#   Original rows: 11,523,111
#   Grouped rows: 2,064,124 (one per load/party/carrier)
#   Columns: ['LOADNUMBER', 'PARTYCODE', 'CARRIER_CODE', 'CARRIER_NAME', 'REFNUMS']
#
# Example REFNUMS array:
#   Load: 512914816
#   REFNUMs: ['3500053163 – Monica Howe', '512914816', '1683011516']
#    LOADNUMBER PARTYCODE CARRIER_CODE                         CARRIER_NAME  \
# 0   512914816  C3556020     T5147519             P W D TRANSPORTATION INC
# 1   516445001  C8871524      T693387  Transportes de Carga Fema, SA de CV
# 2   517227827  C8404407      T707156    Transportes Lar-Mex, S.A. De C.V.
# 3   523533456   C269152     T1570667             Rotex Transportation Inc
# 4   527729067  C8765865     T4412684                     HSD TRUCKING INC
#
#                                              REFNUMS
# 0  [3500053163 – Monica Howe, 512914816, 1683011516]
# 1       [190995424 / 9965264, 516445001, 1716919697]
# 2  [1724404840, 4507875157, 4507875157-10//USAMEX...
# 3  [1723343558, 523533456, YHDYABV6Z6DT884, RD-5561]
# 4              [Green Valley, 527729067, 1722458896]

# %% [markdown]
# ## 3. Extract Load Identifiers from Email Subjects
#
# Create functions to:
# 1. Extract potential load identifiers from email subject lines (patterns like "Load #: 123456", "REF #: 123456", etc.)
# 2. Match extracted identifiers against the crosswalk data to find associated party codes

# %%
import re
from typing import List

def extract_load_identifiers(subject: str) -> List[str]:
    """
    Extract potential load identifiers from an email subject line.
    
    Patterns detected:
    - 8-12 digit numbers (common load number format)
    - Letter-digit combinations (e.g., CHR123456, ABC-123456)
    - "Load #: 123456" or "Load#: 123456"
    - "REF #: 123456" or "REF#: 123456"
    - "Load 123456" or "Load# 123456"
    - "Reference: 123456" or "Ref: 123456"
    - "Order: 123456" or "ORD# 123456"
    - "Shipment: 123456" or "SHIP# 123456"
    - Standalone numbers that could be load numbers (6+ digits)
    - Alphanumeric identifiers like "CHR123456", "L-123456", etc.
    
    Args:
        subject: Email subject line
        
    Returns:
        List of unique potential load identifiers (as strings)
    """
    if pd.isna(subject) or not isinstance(subject, str):
        return []
    
    subject_upper = str(subject).upper()
    identifiers = set()
    
    # Pattern 1: 8-12 digit numbers (common load number format)
    pattern1 = re.findall(r'\b\d{8,12}\b', subject_upper)
    identifiers.update(pattern1)
    
    # Pattern 2: Letter-digit combinations (e.g., CHR123456, ABC-123456)
    pattern2 = re.findall(r'\b[A-Z]{2,4}-?\d{6,10}\b', subject_upper)
    identifiers.update(pattern2)
    
    # Pattern 3: Reference patterns (REF: 123456, REF# 123456, Reference: 123456)
    pattern3 = re.findall(r'(?:REF(?:ERENCE)?)[:\s#]*([A-Z0-9]{6,12})', subject_upper)
    identifiers.update(pattern3)
    
    # Pattern 4: Load patterns (LOAD: 123456, LID: 123456, Load# 123456)
    pattern4 = re.findall(r'(?:LOAD|LID)[:\s#]*([A-Z0-9]{6,12})', subject_upper)
    identifiers.update(pattern4)
    
    # Pattern 5: Order patterns (ORDER: 123456, ORD# 123456)
    pattern5 = re.findall(r'(?:ORDER|ORD)[:\s#]*([A-Z0-9]{6,12})', subject_upper)
    identifiers.update(pattern5)
    
    # Pattern 6: Shipment patterns (SHIPMENT: 123456, SHIP# 123456)
    pattern6 = re.findall(r'(?:SHIPMENT|SHIP)[:\s#]*([A-Z0-9]{6,12})', subject_upper)
    identifiers.update(pattern6)
    
    # Pattern 7: Common prefixes followed by numbers/alphanumeric
    # Matches: "CHR123456", "L-123456", "LOAD-123"
    pattern7 = re.findall(r'\b(?:CHR|L)[:\-\s]?([A-Z0-9]+)\b', subject_upper)
    identifiers.update(pattern7)
    
    # Pattern 8: Standalone numbers that could be load numbers (6-7 digits)
    # This catches shorter numbers that might be load IDs without keywords
    pattern8 = re.findall(r'\b(\d{6,7})\b', subject_upper)
    identifiers.update(pattern8)
    
    # Pattern 9: Hash/pound sign followed by number
    # Matches: "#123456", "# 123456"
    pattern9 = re.findall(r'#\s*(\d{6,12})\b', subject_upper)
    identifiers.update(pattern9)
    
    # Clean up and return unique identifiers
    # Remove any empty strings and ensure all are uppercase
    cleaned_identifiers = [id.strip().upper() for id in identifiers if id.strip()]
    
    return list(set(cleaned_identifiers))  # Return unique values only


print("✓ Load identifier extraction function created")
print("  - extract_load_identifiers(): Extract IDs from subject line")
# Out:
# ✓ Load identifier extraction function created
#   - extract_load_identifiers(): Extract IDs from subject line

# %%
# Batch processing function to enrich dataframe with crosswalk data
def enrich_emails_with_crosswalk(email_df, crosswalk_df, chunk_size=100000):
    """
    Process emails in chunks and add loadnumber, partycode, carrier_code, and carrier_name columns from crosswalk matches.
    
    Args:
        email_df: DataFrame with email data including SUBJECT column
        crosswalk_df: DataFrame with LOADNUMBER, PARTYCODE, CARRIER_CODE, CARRIER_NAME, REFNUMS (array) columns
        chunk_size: Number of rows to process per chunk
        
    Returns:
        DataFrame with added columns: extracted_identifiers, matched_refnums, loadnumbers, partycodes, carrier_code, carrier_name, match_count
    """
    import gc
    
    total_rows = len(email_df)
    num_chunks = (total_rows + chunk_size - 1) // chunk_size
    
    print(f"\n{'='*80}")
    print(f"Enriching Email DataFrame with Crosswalk Data (Batch Processing)")
    print(f"{'='*80}")
    print(f"Total emails: {total_rows:,}")
    print(f"Chunk size: {chunk_size:,}")
    print(f"Number of chunks: {num_chunks}")
    print(f"Crosswalk records: {len(crosswalk_df):,}")
    print(f"{'='*80}\n")
    
    # Build crosswalk lookup once for efficiency (optimized vectorized approach)
    # New structure: REFNUM -> load/party/carrier info
    print("Building crosswalk lookup dictionary (optimized)...")
    crosswalk_lookup = {}
    
    # Use vectorized operations instead of iterrows for better performance
    for idx in range(len(crosswalk_df)):
        row = crosswalk_df.iloc[idx]
        refnums_list = row['REFNUMS']
        
        if isinstance(refnums_list, list) and len(refnums_list) > 0:
            # Pre-create the lookup value once for all REFNUMs in this row
            lookup_value = {
                'loadnumber': str(row['LOADNUMBER']),
                'partycode': row['PARTYCODE'],
                'carrier_code': row['CARRIER_CODE'] if pd.notna(row.get('CARRIER_CODE')) else None,
                'carrier_name': row['CARRIER_NAME'] if pd.notna(row.get('CARRIER_NAME')) else None
            }
            
            # Map each REFNUM to the same lookup value
            for refnum in refnums_list:
                if pd.notna(refnum):
                    refnum_upper = str(refnum).upper()
                    if refnum_upper:
                        crosswalk_lookup[refnum_upper] = lookup_value
    
    print(f"✓ Crosswalk lookup built with {len(crosswalk_lookup):,} unique REFNUMs\n")
    
    # Initialize result lists
    all_extracted_ids = []
    all_matched_refnums = []
    all_loadnumbers = []
    all_partycodes = []
    all_carrier_codes = []
    all_carrier_names = []
    all_match_counts = []
    
    # Process in chunks
    for chunk_num in range(num_chunks):
        start_idx = chunk_num * chunk_size
        end_idx = min((chunk_num + 1) * chunk_size, total_rows)
        
        print(f"📧 Processing chunk {chunk_num + 1}/{num_chunks}: rows {start_idx:,} to {end_idx:,}...")
        
        # Get chunk
        chunk = email_df.iloc[start_idx:end_idx]
        
        # Process each email in chunk
        chunk_extracted = []
        chunk_matched = []
        chunk_loadnums = []
        chunk_partycodes = []
        chunk_carrier_codes = []
        chunk_carrier_names = []
        chunk_counts = []
        
        for _, row in chunk.iterrows():
            # Extract identifiers
            extracted_ids = extract_load_identifiers(row['SUBJECT'])
            
            # Match against crosswalk
            matched_refnums = []
            loadnumbers = set()
            partycodes = set()
            carrier_code = None  # Single value, not a set
            carrier_name = None  # Single value, not a set
            
            for identifier in extracted_ids:
                identifier_upper = identifier.upper()
                if identifier_upper in crosswalk_lookup:
                    matched_refnums.append(identifier_upper)
                    loadnumbers.add(crosswalk_lookup[identifier_upper]['loadnumber'])
                    partycodes.add(crosswalk_lookup[identifier_upper]['partycode'])
                    # Get the first carrier_code and carrier_name found (since there's only one per email)
                    if carrier_code is None:
                        carrier_code = crosswalk_lookup[identifier_upper]['carrier_code']
                    if carrier_name is None:
                        carrier_name = crosswalk_lookup[identifier_upper]['carrier_name']
            
            # Store results
            chunk_extracted.append(extracted_ids)
            chunk_matched.append(matched_refnums)
            chunk_loadnums.append(list(loadnumbers))
            chunk_partycodes.append(list(partycodes))
            chunk_carrier_codes.append(carrier_code)  # Store as single value
            chunk_carrier_names.append(carrier_name)  # Store as single value
            chunk_counts.append(len(matched_refnums))
        
        # Add chunk results to all results
        all_extracted_ids.extend(chunk_extracted)
        all_matched_refnums.extend(chunk_matched)
        all_loadnumbers.extend(chunk_loadnums)
        all_partycodes.extend(chunk_partycodes)
        all_carrier_codes.extend(chunk_carrier_codes)
        all_carrier_names.extend(chunk_carrier_names)
        all_match_counts.extend(chunk_counts)
        
        # Clean up
        del chunk
        gc.collect()
    
    # Add columns to original dataframe
    print(f"\n✓ All chunks processed. Adding columns to dataframe...")
    email_df['extracted_identifiers'] = all_extracted_ids
    email_df['matched_refnums'] = all_matched_refnums
    email_df['loadnumbers'] = all_loadnumbers
    email_df['partycodes'] = all_partycodes
    email_df['carrier_code'] = all_carrier_codes  # Single string value
    email_df['carrier_name'] = all_carrier_names  # Single string value
    email_df['match_count'] = all_match_counts
    
    # Print summary statistics
    print(f"\n{'='*80}")
    print(f"📊 Enrichment Summary")
    print(f"{'='*80}")
    
    emails_with_extracted = sum(1 for x in all_extracted_ids if len(x) > 0)
    emails_with_matches = sum(1 for x in all_match_counts if x > 0)
    total_loadnums = sum(len(x) for x in all_loadnumbers)
    total_partycodes = sum(len(x) for x in all_partycodes)
    emails_with_carrier_code = sum(1 for x in all_carrier_codes if pd.notna(x))
    
    print(f"Emails with extracted identifiers: {emails_with_extracted:,} ({emails_with_extracted/total_rows*100:.1f}%)")
    print(f"Emails with crosswalk matches: {emails_with_matches:,} ({emails_with_matches/total_rows*100:.1f}%)")
    print(f"Total load numbers found: {total_loadnums:,}")
    print(f"Total party codes found: {total_partycodes:,}")
    print(f"Emails with carrier code: {emails_with_carrier_code:,} ({emails_with_carrier_code/total_rows*100:.1f}%)")
    print(f"Average identifiers per email: {sum(len(x) for x in all_extracted_ids)/total_rows:.2f}")
    print(f"Average matches per email: {sum(all_match_counts)/total_rows:.2f}")
    print(f"{'='*80}\n")
    
    return email_df

print("✅ Batch enrichment function created: enrich_emails_with_crosswalk()")
# Out:
# ✅ Batch enrichment function created: enrich_emails_with_crosswalk()

# %%
def extract_load_identifiers_from_body(body_text: str, limit: int = 20) -> List[str]:
    """
    Extract potential load identifiers from cleaned email body text.
    
    Uses same patterns as subject line extraction but applies to email body.
    Limits results to avoid extracting too many false positives from long emails.
    
    Args:
        body_text: Cleaned email body text
        limit: Maximum number of identifiers to extract (default: 20)
        
    Returns:
        List of unique potential load identifiers (as strings)
    """
    if pd.isna(body_text) or body_text == '':
        return []
    
    body_upper = str(body_text).upper()
    identifiers = set()
    
    # Pattern 1: 8-12 digit numbers (common load number format)
    pattern1 = re.findall(r'\b\d{8,12}\b', body_upper)
    identifiers.update(pattern1)
    
    # Pattern 2: Letter-digit combinations (e.g., CHR123456, ABC-123456)
    pattern2 = re.findall(r'\b[A-Z]{2,4}-?\d{6,10}\b', body_upper)
    identifiers.update(pattern2)
    
    # Pattern 3: Reference patterns (REF: 123456, REF# 123456, Reference: 123456)
    pattern3 = re.findall(r'(?:REF(?:ERENCE)?)[:\s#]*([A-Z0-9]{6,12})', body_upper)
    identifiers.update(pattern3)
    
    # Pattern 4: Load patterns (LOAD: 123456, LID: 123456, Load# 123456)
    pattern4 = re.findall(r'(?:LOAD|LID)[:\s#]*([A-Z0-9]{6,12})', body_upper)
    identifiers.update(pattern4)
    
    # Pattern 5: Order patterns (ORDER: 123456, ORD# 123456)
    pattern5 = re.findall(r'(?:ORDER|ORD)[:\s#]*([A-Z0-9]{6,12})', body_upper)
    identifiers.update(pattern5)
    
    # Pattern 6: Shipment patterns (SHIPMENT: 123456, SHIP# 123456)
    pattern6 = re.findall(r'(?:SHIPMENT|SHIP)[:\s#]*([A-Z0-9]{6,12})', body_upper)
    identifiers.update(pattern6)
    
    # Pattern 7: Common prefixes followed by numbers/alphanumeric
    pattern7 = re.findall(r'\b(?:CHR|L)[:\-\s]?([A-Z0-9]+)\b', body_upper)
    identifiers.update(pattern7)
    
    # Pattern 8: Hash/pound sign followed by number
    pattern8 = re.findall(r'#\s*(\d{6,12})\b', body_upper)
    identifiers.update(pattern8)
    
    # NOTE: Deliberately excluding 6-7 digit standalone numbers from body text
    # to reduce false positives (dates, phone numbers, etc.)
    
    # Clean up and return unique identifiers
    cleaned_identifiers = [id.strip().upper() for id in identifiers if id.strip()]
    
    # Filter out invalid identifiers:
    # 1. All-string identifiers (no digits) - e.g., "ABC", "LOAD"
    # 2. Single character identifiers - e.g., "A", "1"
    filtered_identifiers = []
    for identifier in cleaned_identifiers:
        # Skip single character identifiers
        if len(identifier) <= 1:
            continue
        # Skip all-letter identifiers (must contain at least one digit)
        if identifier.isalpha():
            continue
        # Keep valid identifiers
        filtered_identifiers.append(identifier)
    
    unique_identifiers = list(set(filtered_identifiers))
    
    # Limit results to avoid extracting too many from long emails
    return unique_identifiers[:limit]


print("✓ Body text identifier extraction function created")
print("  - extract_load_identifiers_from_body(): Extract IDs from email body")
print("  - Excludes: single characters, all-letter identifiers")
print("  - Note: Limits to 20 identifiers per email to reduce false positives")
# Out:
# ✓ Body text identifier extraction function created
#   - extract_load_identifiers_from_body(): Extract IDs from email body
#   - Excludes: single characters, all-letter identifiers
#   - Note: Limits to 20 identifiers per email to reduce false positives

# %% [markdown]
# ### Extract Load Identifiers from Email Body Text
#
# Similar to subject line extraction, extract potential load identifiers from the cleaned email body text.

# %%
def enrich_emails_with_crosswalk_enhanced(email_df, crosswalk_df, chunk_size=100000, 
                                          extract_from_body=True, body_column='EMAIL_TEXT_CLEAN'):
    """
    Process emails in chunks and extract identifiers from BOTH subject and body text.
    
    Args:
        email_df: DataFrame with email data including SUBJECT and body text columns
        crosswalk_df: DataFrame with LOADNUMBER, PARTYCODE, CARRIER_CODE, CARRIER_NAME, REFNUMS (array) columns
        chunk_size: Number of rows to process per chunk
        extract_from_body: Whether to also extract from email body (default: True)
        body_column: Column name containing cleaned email body text (default: 'EMAIL_TEXT_CLEAN')
        
    Returns:
        DataFrame with added columns including identifiers from subject AND body
    """
    import gc
    
    total_rows = len(email_df)
    num_chunks = (total_rows + chunk_size - 1) // chunk_size
    
    print(f"\n{'='*80}")
    print(f"Enhanced Email Enrichment (Subject + Body Text Extraction)")
    print(f"{'='*80}")
    print(f"Total emails: {total_rows:,}")
    print(f"Chunk size: {chunk_size:,}")
    print(f"Number of chunks: {num_chunks}")
    print(f"Crosswalk records: {len(crosswalk_df):,}")
    print(f"Extract from body: {extract_from_body}")
    if extract_from_body:
        print(f"Body text column: {body_column}")
    print(f"{'='*80}\n")
    
    # Build crosswalk lookup once for efficiency (optimized vectorized approach)
    # New structure: REFNUM -> load/party/carrier info
    print("Building crosswalk lookup dictionary (optimized)...")
    crosswalk_lookup = {}
    
    # Use vectorized operations instead of iterrows for better performance
    for idx in range(len(crosswalk_df)):
        row = crosswalk_df.iloc[idx]
        refnums_list = row['REFNUMS']
        
        if isinstance(refnums_list, list) and len(refnums_list) > 0:
            # Pre-create the lookup value once for all REFNUMs in this row
            lookup_value = {
                'loadnumber': str(row['LOADNUMBER']),
                'partycode': row['PARTYCODE'],
                'carrier_code': row['CARRIER_CODE'] if pd.notna(row.get('CARRIER_CODE')) else None,
                'carrier_name': row['CARRIER_NAME'] if pd.notna(row.get('CARRIER_NAME')) else None
            }
            
            # Map each REFNUM to the same lookup value
            for refnum in refnums_list:
                if pd.notna(refnum):
                    refnum_upper = str(refnum).upper()
                    if refnum_upper:
                        crosswalk_lookup[refnum_upper] = lookup_value
    
    print(f"✓ Crosswalk lookup built with {len(crosswalk_lookup):,} unique REFNUMs\n")
    
    # Initialize result lists
    all_extracted_ids_subject = []
    all_extracted_ids_body = []
    all_extracted_ids_combined = []
    all_matched_refnums = []
    all_loadnumbers = []
    all_partycodes = []
    all_carrier_codes = []
    all_carrier_names = []
    all_match_counts = []
    all_match_source = []  # Track where match came from: 'subject', 'body', or 'both'
    
    # Process in chunks
    for chunk_num in range(num_chunks):
        start_idx = chunk_num * chunk_size
        end_idx = min((chunk_num + 1) * chunk_size, total_rows)
        
        print(f"📧 Processing chunk {chunk_num + 1}/{num_chunks}: rows {start_idx:,} to {end_idx:,}...")
        
        # Get chunk
        chunk = email_df.iloc[start_idx:end_idx]
        
        # Process each email in chunk
        chunk_extracted_subject = []
        chunk_extracted_body = []
        chunk_extracted_combined = []
        chunk_matched = []
        chunk_loadnums = []
        chunk_partycodes = []
        chunk_carrier_codes = []
        chunk_carrier_names = []
        chunk_counts = []
        chunk_sources = []
        
        for _, row in chunk.iterrows():
            # Extract identifiers from subject
            extracted_ids_subject = extract_load_identifiers(row['SUBJECT'])
            
            # Extract identifiers from body (if enabled)
            extracted_ids_body = []
            if extract_from_body and body_column in email_df.columns:
                extracted_ids_body = extract_load_identifiers_from_body(row[body_column])
            
            # Combine unique identifiers from both sources
            all_ids = list(set(extracted_ids_subject + extracted_ids_body))
            
            # Match against crosswalk
            matched_refnums = []
            matched_from_subject = []
            matched_from_body = []
            loadnumbers = set()
            partycodes = set()
            carrier_code = None
            carrier_name = None
            
            for identifier in all_ids:
                identifier_upper = identifier.upper()
                if identifier_upper in crosswalk_lookup:
                    matched_refnums.append(identifier_upper)
                    loadnumbers.add(crosswalk_lookup[identifier_upper]['loadnumber'])
                    partycodes.add(crosswalk_lookup[identifier_upper]['partycode'])
                    
                    # Track source of match
                    if identifier_upper in [x.upper() for x in extracted_ids_subject]:
                        matched_from_subject.append(identifier_upper)
                    if identifier_upper in [x.upper() for x in extracted_ids_body]:
                        matched_from_body.append(identifier_upper)
                    
                    # Get the first carrier_code and carrier_name found
                    if carrier_code is None:
                        carrier_code = crosswalk_lookup[identifier_upper]['carrier_code']
                    if carrier_name is None:
                        carrier_name = crosswalk_lookup[identifier_upper]['carrier_name']
            
            # Determine match source
            if len(matched_from_subject) > 0 and len(matched_from_body) > 0:
                match_source = 'both'
            elif len(matched_from_subject) > 0:
                match_source = 'subject'
            elif len(matched_from_body) > 0:
                match_source = 'body'
            else:
                match_source = None
            
            # Store results
            chunk_extracted_subject.append(extracted_ids_subject)
            chunk_extracted_body.append(extracted_ids_body)
            chunk_extracted_combined.append(all_ids)
            chunk_matched.append(matched_refnums)
            chunk_loadnums.append(list(loadnumbers))
            chunk_partycodes.append(list(partycodes))
            chunk_carrier_codes.append(carrier_code)
            chunk_carrier_names.append(carrier_name)
            chunk_counts.append(len(matched_refnums))
            chunk_sources.append(match_source)
        
        # Add chunk results to all results
        all_extracted_ids_subject.extend(chunk_extracted_subject)
        all_extracted_ids_body.extend(chunk_extracted_body)
        all_extracted_ids_combined.extend(chunk_extracted_combined)
        all_matched_refnums.extend(chunk_matched)
        all_loadnumbers.extend(chunk_loadnums)
        all_partycodes.extend(chunk_partycodes)
        all_carrier_codes.extend(chunk_carrier_codes)
        all_carrier_names.extend(chunk_carrier_names)
        all_match_counts.extend(chunk_counts)
        all_match_source.extend(chunk_sources)
        
        # Clean up
        del chunk
        gc.collect()
    
    # Add columns to original dataframe
    print(f"\n✓ All chunks processed. Adding columns to dataframe...")
    email_df['extracted_ids_subject'] = all_extracted_ids_subject
    email_df['extracted_ids_body'] = all_extracted_ids_body
    email_df['extracted_identifiers'] = all_extracted_ids_combined
    email_df['matched_refnums'] = all_matched_refnums
    email_df['loadnumbers'] = all_loadnumbers
    email_df['partycodes'] = all_partycodes
    email_df['carrier_code'] = all_carrier_codes
    email_df['carrier_name'] = all_carrier_names
    email_df['match_count'] = all_match_counts
    email_df['match_source'] = all_match_source
    
    # Print summary statistics
    print(f"\n{'='*80}")
    print(f"📊 Enhanced Enrichment Summary")
    print(f"{'='*80}")
    
    emails_with_extracted_subject = sum(1 for x in all_extracted_ids_subject if len(x) > 0)
    emails_with_extracted_body = sum(1 for x in all_extracted_ids_body if len(x) > 0)
    emails_with_extracted_any = sum(1 for x in all_extracted_ids_combined if len(x) > 0)
    emails_with_matches = sum(1 for x in all_match_counts if x > 0)
    
    # Count matches by source
    matches_from_subject = sum(1 for x in all_match_source if x == 'subject')
    matches_from_body = sum(1 for x in all_match_source if x == 'body')
    matches_from_both = sum(1 for x in all_match_source if x == 'both')
    
    total_loadnums = sum(len(x) for x in all_loadnumbers)
    total_partycodes = sum(len(x) for x in all_partycodes)
    emails_with_carrier_code = sum(1 for x in all_carrier_codes if pd.notna(x))
    
    print(f"\n📧 Identifier Extraction:")
    print(f"  From subject only: {emails_with_extracted_subject:,} emails")
    print(f"  From body only: {emails_with_extracted_body:,} emails")
    print(f"  From either source: {emails_with_extracted_any:,} emails ({emails_with_extracted_any/total_rows*100:.1f}%)")
    
    print(f"\n🎯 Crosswalk Matches:")
    print(f"  Total emails with matches: {emails_with_matches:,} ({emails_with_matches/total_rows*100:.1f}%)")
    print(f"  Matched from subject: {matches_from_subject:,}")
    print(f"  Matched from body: {matches_from_body:,}")
    print(f"  Matched from both: {matches_from_both:,}")
    
    print(f"\n📦 Results:")
    print(f"  Total load numbers found: {total_loadnums:,}")
    print(f"  Total party codes found: {total_partycodes:,}")
    print(f"  Emails with carrier code: {emails_with_carrier_code:,} ({emails_with_carrier_code/total_rows*100:.1f}%)")
    print(f"  Average identifiers per email: {sum(len(x) for x in all_extracted_ids_combined)/total_rows:.2f}")
    print(f"  Average matches per email: {sum(all_match_counts)/total_rows:.2f}")
    print(f"{'='*80}\n")
    
    return email_df

print("✅ Enhanced enrichment function created: enrich_emails_with_crosswalk_enhanced()")
print("   - Extracts from both SUBJECT and EMAIL_TEXT_CLEAN")
print("   - Tracks match source (subject/body/both)")
# Out:
# ✅ Enhanced enrichment function created: enrich_emails_with_crosswalk_enhanced()
#    - Extracts from both SUBJECT and EMAIL_TEXT_CLEAN
#    - Tracks match source (subject/body/both)

# %% [markdown]
# ### Enhanced Enrichment: Extract from Subject AND Body Text
#
# This enhanced version extracts identifiers from both the subject line and email body text.

# %% [markdown]
# ### Enrich Email DataFrame with Crosswalk Data (Batch Processing)

# %%
# # Enrich the email dataframe with crosswalk data using batch processing
# # This will add the following columns:
# # - extracted_identifiers: All IDs found in subject
# # - matched_refnums: IDs that matched in crosswalk
# # - loadnumbers: Load numbers from crosswalk
# # - partycodes: Party codes from crosswalk
# # - match_count: Number of matches found

# df_enriched = enrich_emails_with_crosswalk(
#     email_df=df,
#     crosswalk_df=crosswalk_df,
#     chunk_size=100000  # Adjust based on your memory constraints
# )

# print("✅ Dataframe enriched with crosswalk data!")
# print(f"\nNew columns added: {['extracted_identifiers', 'matched_refnums', 'loadnumbers', 'partycodes', 'match_count']}")
# print(f"\nDataframe shape: {df_enriched.shape}")
# print(f"\nSample of enriched data:")
# df_enriched[['SUBJECT', 'extracted_identifiers', 'matched_refnums', 'loadnumbers', 'partycodes', 'match_count']].head(10)

# %%
# ENHANCED ENRICHMENT: Extract from BOTH Subject and Body Text
# This will significantly improve match rates by finding load identifiers
# mentioned in the email body that aren't in the subject line

df_enriched = enrich_emails_with_crosswalk_enhanced(
    email_df=df,
    crosswalk_df=crosswalk_df,
    chunk_size=100000,
    extract_from_body=True,
    body_column='EMAIL_TEXT_CLEAN'
)

print("\n✅ Enhanced dataframe enrichment complete!")
print(f"\nNew columns added:")
print(f"  - extracted_ids_subject: IDs found in subject line")
print(f"  - extracted_ids_body: IDs found in email body")
print(f"  - extracted_identifiers: Combined unique IDs from both")
print(f"  - matched_refnums: IDs that matched in crosswalk")
print(f"  - loadnumbers: Load numbers from crosswalk")
print(f"  - partycodes: Party codes from crosswalk")
print(f"  - carrier_code: Carrier code")
print(f"  - carrier_name: Carrier name")
print(f"  - match_count: Number of matches found")
print(f"  - match_source: Where match came from ('subject', 'body', or 'both')")

print(f"\nDataframe shape: {df_enriched.shape}")
print(f"\nSample of enriched data:")
df_enriched[['CONVERSATION_ID','MESSAGE_ID','SUBJECT', 'extracted_ids_subject', 'extracted_ids_body', 'match_source', 'match_count']].head(10)
# Out:
# ================================================================================
# Enhanced Email Enrichment (Subject + Body Text Extraction)
# ================================================================================
# Total emails: 494,317
# Chunk size: 100,000
# Number of chunks: 5
# Crosswalk records: 2,064,124
# Extract from body: True
# Body text column: EMAIL_TEXT_CLEAN
# ================================================================================
#
# Building crosswalk lookup dictionary (optimized)...
# ✓ Crosswalk lookup built with 8,069,249 unique REFNUMs
#
# 📧 Processing chunk 1/5: rows 0 to 100,000...
# ✓ Crosswalk lookup built with 8,069,249 unique REFNUMs
#
# 📧 Processing chunk 1/5: rows 0 to 100,000...
# 📧 Processing chunk 2/5: rows 100,000 to 200,000...
# 📧 Processing chunk 2/5: rows 100,000 to 200,000...
# 📧 Processing chunk 3/5: rows 200,000 to 300,000...
# 📧 Processing chunk 3/5: rows 200,000 to 300,000...
# 📧 Processing chunk 4/5: rows 300,000 to 400,000...
# 📧 Processing chunk 4/5: rows 300,000 to 400,000...
# 📧 Processing chunk 5/5: rows 400,000 to 494,317...
# 📧 Processing chunk 5/5: rows 400,000 to 494,317...
#
# ✓ All chunks processed. Adding columns to dataframe...
#
# ✓ All chunks processed. Adding columns to dataframe...
#
# ================================================================================
# 📊 Enhanced Enrichment Summary
# ================================================================================
#
# ================================================================================
# 📊 Enhanced Enrichment Summary
# ================================================================================
#
# 📧 Identifier Extraction:
#   From subject only: 339,926 emails
#   From body only: 436,281 emails
#   From either source: 463,217 emails (93.7%)
#
# 🎯 Crosswalk Matches:
#   Total emails with matches: 310,224 (62.8%)
#   Matched from subject: 27,757
#   Matched from body: 119,025
#   Matched from both: 163,442
#
# 📦 Results:
#   Total load numbers found: 716,283
#   Total party codes found: 378,760
#   Emails with carrier code: 310,224 (62.8%)
#   Average identifiers per email: 4.46
#   Average matches per email: 1.69
# ================================================================================
#
#
# 📧 Identifier Extraction:
#   From subject only: 339,926 emails
#   From body only: 436,281 emails
#   From either source: 463,217 emails (93.7%)
#
# 🎯 Crosswalk Matches:
#   Total emails with matches: 310,224 (62.8%)
#   Matched from subject: 27,757
#   Matched from body: 119,025
#   Matched from both: 163,442
#
# 📦 Results:
#   Total load numbers found: 716,283
#   Total party codes found: 378,760
#   Emails with carrier code: 310,224 (62.8%)
#   Average identifiers per email: 4.46
#   Average matches per email: 1.69
# ================================================================================
#
#
# ✅ Enhanced dataframe enrichment complete!
#
# New columns added:
#   - extracted_ids_subject: IDs found in subject line
#   - extracted_ids_body: IDs found in email body
#   - extracted_identifiers: Combined unique IDs from both
#   - matched_refnums: IDs that matched in crosswalk
#   - loadnumbers: Load numbers from crosswalk
#   - partycodes: Party codes from crosswalk
#   - carrier_code: Carrier code
#   - carrier_name: Carrier name
#   - match_count: Number of matches found
#   - match_source: Where match came from ('subject', 'body', or 'both')
#
# Dataframe shape: (494317, 30)
#
# Sample of enriched data:
#
# ✅ Enhanced dataframe enrichment complete!
#
# New columns added:
#   - extracted_ids_subject: IDs found in subject line
#   - extracted_ids_body: IDs found in email body
#   - extracted_identifiers: Combined unique IDs from both
#   - matched_refnums: IDs that matched in crosswalk
#   - loadnumbers: Load numbers from crosswalk
#   - partycodes: Party codes from crosswalk
#   - carrier_code: Carrier code
#   - carrier_name: Carrier name
#   - match_count: Number of matches found
#   - match_source: Where match came from ('subject', 'body', or 'both')
#
# Dataframe shape: (494317, 30)
#
# Sample of enriched data:
#                                      CONVERSATION_ID  \
# 0  AAQkAGI1ZTM2ODMxLWI1NmYtNGM5OC05NjY1LTdhMDk2MW...
# 1  AAQkADI3YTc5NjQyLTI5OWQtNGI1ZC1hN2UzLThjZmNjNW...
# 2  AAQkADRmOGE2NjQyLWVjYmMtNGE0Ni1hOWEzLTIwMTQwYT...
# 3  AAQkAGMyNmY1NGI1LTdmOGItNDRjZC1iOWRjLTkzYzkzND...
# 4  AAQkADIzY2I2OTA3LWUzMGQtNDE0My05NjI3LTRjZjY5MW...
# 5  AAQkADEwYzc1MTljLWZjZmEtNGNhOS04YjExLWEwOWUwYW...
# 6  AAQkAGM0YTliYjQwLTYzM2ItNDQyNC04NzM2LTcwNWFjYz...
# 7  AAQkADlhYmRjYzQyLTUzZTItNGIzOC04NmU0LTczZGMyNz...
# 8  AAQkAGViYmU3YjVmLTYyZDMtNGMwMi1hMTM2LTNlMGYwOW...
# 9  AAQkADhlMDNlNzMzLTVjNzYtNGU5NC1iYWM1LTZiMjgwYj...
#
#                              MESSAGE_ID  \
# 0  5128cfe2-05a8-4344-84b6-68cd25d8b20d
# 1  3674a835-f09b-4cdd-876a-a180e3282fac
# 2  0db9b2ce-4f41-41ab-8743-c3e521f917ae
# 3  b5a4ed8e-82a0-428b-83df-ec9486d286f6
# 4  d0977b7b-c7d4-465c-baad-49dec9164fac
# 5  ba103e0f-57c7-461c-84ef-be13928e8062
# 6  8efb9cac-33cd-4840-a654-2ceb8c770157
# 7  b0619335-ab46-48c6-a1dd-97972cdda1bb
# 8  9238ee8a-bb31-40f4-a147-f9a83e8efefa
# 9  d7a9ddeb-cbf8-49f3-bd1d-9246b5a405ad
#
#                                              SUBJECT  \
# 0    回复： Re: 回复： Re: 回复： Re: 回复： 547005356 need ETa
# 1  RE: GKDRALA260763 RE: [INTERNAL]:RE: NEED BOL ...
# 2                             CH ROBINSON WEST 02-19
# 3                           Re: Driver ETA 244723172
# 4                                RE: IMDL Loads 2/27
# 5                       RE: Booked Load #: 548175887
# 6                           RE: anyone around today?
# 7                                           RE: Ward
# 8  Re: Request for Pickup ETA - Load # 545573520 ...
# 9                                          546925510
#
#                                extracted_ids_subject  \
# 0                                        [547005356]
# 1  [219752, 218844, 805403603, 219565, 805403600,...
# 2                                                 []
# 3                                        [244723172]
# 4                                             [OADS]
# 5                                   [548175887, OAD]
# 6                                                 []
# 7                                                 []
# 8                          [2098797, OAD, 545573520]
# 9                                        [546925510]
#
#                                   extracted_ids_body match_source  match_count
# 0                                        [547005356]         both            1
# 1  [805403605, 220712, 547735856, 805403603, 8054...         None            0
# 2  [102117721, 11635357, 20423935, 20425744, 1721...         body           14
# 3  [244677637, 610687981, 244723172, 128522, 5484...         both            7
# 4  [OFA-329976, OFA-320450, 545324675, OFA-327904...         None            0
# 5  [20260408, 41562520, 7000515259, 20260325, 548...         both            4
# 6                                                 []         None            0
# 7                                           [128522]         body            1
# 8                      [2298256, 545573520, 2098797]         None            0
# 9                                                 []      subject            1

# %% [markdown]
# ### Match Success Rate Summary
#
# Analyze how many emails successfully matched to the crosswalk data.

# %%
# Analyze match success rate for the enriched dataframe
print("="*80)
print("📊 EMAIL MATCH SUCCESS RATE SUMMARY")
print("="*80)

total_emails = len(df_enriched)
emails_with_matches = len(df_enriched[df_enriched['match_count'] > 0])
emails_without_matches = total_emails - emails_with_matches

match_rate = (emails_with_matches / total_emails * 100) if total_emails > 0 else 0

print(f"\nTotal emails analyzed: {total_emails:,}")
print(f"\n✅ Emails with successful matches: {emails_with_matches:,}")
print(f"   Match rate: {match_rate:.2f}%")
print(f"\n❌ Emails without matches: {emails_without_matches:,}")
print(f"   No-match rate: {100 - match_rate:.2f}%")

# Breakdown by match source
if 'match_source' in df_enriched.columns:
    print(f"\n{'Match Source Breakdown:':-^80}")
    
    matched_from_subject = len(df_enriched[df_enriched['match_source'] == 'subject'])
    matched_from_body = len(df_enriched[df_enriched['match_source'] == 'body'])
    matched_from_both = len(df_enriched[df_enriched['match_source'] == 'both'])
    
    print(f"  Subject only: {matched_from_subject:,} ({matched_from_subject/total_emails*100:.2f}%)")
    print(f"  Body only: {matched_from_body:,} ({matched_from_body/total_emails*100:.2f}%)")
    print(f"  Both sources: {matched_from_both:,} ({matched_from_both/total_emails*100:.2f}%)")
    
    # Calculate value of body text extraction
    matches_including_body = matched_from_body + matched_from_both
    print(f"\n  💡 Total matches including body text: {matches_including_body:,}")
    print(f"     Additional value from body extraction: {matched_from_body + matched_from_both - matched_from_subject:,} emails")

# Statistics on match counts
if emails_with_matches > 0:
    matched_emails = df_enriched[df_enriched['match_count'] > 0]
    avg_matches = matched_emails['match_count'].mean()
    max_matches = matched_emails['match_count'].max()
    
    print(f"\n{'Match Statistics (for matched emails only):':-^80}")
    print(f"  Average matches per email: {avg_matches:.2f}")
    print(f"  Maximum matches in single email: {max_matches}")
    
    # Distribution of match counts
    match_count_dist = matched_emails['match_count'].value_counts().sort_index()
    print(f"\n  Match count distribution:")
    for count, num_emails in match_count_dist.head(10).items():
        print(f"    {int(count)} match(es): {num_emails:,} emails")

print("="*80)
# Out:
# ================================================================================
# 📊 EMAIL MATCH SUCCESS RATE SUMMARY
# ================================================================================
#
# Total emails analyzed: 494,317
#
# ✅ Emails with successful matches: 310,224
#    Match rate: 62.76%
#
# ❌ Emails without matches: 184,093
#    No-match rate: 37.24%
#
# ----------------------------Match Source Breakdown:-----------------------------
#
# Total emails analyzed: 494,317
#
# ✅ Emails with successful matches: 310,224
#    Match rate: 62.76%
#
# ❌ Emails without matches: 184,093
#    No-match rate: 37.24%
#
# ----------------------------Match Source Breakdown:-----------------------------
#   Subject only: 27,757 (5.62%)
#   Body only: 119,025 (24.08%)
#   Both sources: 163,442 (33.06%)
#
#   💡 Total matches including body text: 282,467
#      Additional value from body extraction: 254,710 emails
#   Subject only: 27,757 (5.62%)
#   Body only: 119,025 (24.08%)
#   Both sources: 163,442 (33.06%)
#
#   💡 Total matches including body text: 282,467
#      Additional value from body extraction: 254,710 emails
#
# ------------------Match Statistics (for matched emails only):-------------------
#   Average matches per email: 2.69
#   Maximum matches in single email: 23
#
#   Match count distribution:
#     1 match(es): 177,873 emails
#     2 match(es): 60,804 emails
#     3 match(es): 19,760 emails
#     4 match(es): 11,180 emails
#     5 match(es): 5,971 emails
#     6 match(es): 5,407 emails
#     7 match(es): 3,298 emails
#     8 match(es): 3,828 emails
#     9 match(es): 2,502 emails
#     10 match(es): 2,876 emails
# ================================================================================
#
# ------------------Match Statistics (for matched emails only):-------------------
#   Average matches per email: 2.69
#   Maximum matches in single email: 23
#
#   Match count distribution:
#     1 match(es): 177,873 emails
#     2 match(es): 60,804 emails
#     3 match(es): 19,760 emails
#     4 match(es): 11,180 emails
#     5 match(es): 5,971 emails
#     6 match(es): 5,407 emails
#     7 match(es): 3,298 emails
#     8 match(es): 3,828 emails
#     9 match(es): 2,502 emails
#     10 match(es): 2,876 emails
# ================================================================================

# %%
len(df_enriched)
# Out:
# 494317

# %%
df_enriched = df_enriched.drop_duplicates(subset = ['MESSAGE_ID'], keep='first')
len(df_enriched)
# Out:
# 494317

# %%
print(df_enriched[df_enriched['MESSAGE_ID']=='4fae0408-293b-4100-8bfc-86ac8c3b227d']['EMAIL_TEXT_CLEAN'])
# Out:
# 359905    Yes just arrived &nbsp; From: P66trans &lt;P66...
# Name: EMAIL_TEXT_CLEAN, dtype: object

# %%
from IPython.display import display, HTML

# Display a single cell's content in a scrollable box
def show_cell_scrollable(text, max_height='400px', width='100%'):
    """Display text in a scrollable container"""
    html = f'''
    <div style="max-height: {max_height}; 
                width: {width}; 
                overflow-y: auto; 
                overflow-x: auto;
                border: 1px solid #ccc; 
                padding: 15px; 
                background-color: #f9f9f9;
                font-family: monospace;
                white-space: pre-wrap;
                word-wrap: break-word;">
        {text}
    </div>
    '''
    display(HTML(html))

# Example: Show a specific email
email_text = df_enriched[df_enriched['MESSAGE_ID']=='4fae0408-293b-4100-8bfc-86ac8c3b227d']['EMAIL_TEXT_CLEAN'].values[0]
show_cell_scrollable(email_text, max_height='500px')
# Out:
#     <div style="max-height: 500px;
#                 width: 100%;
#                 overflow-y: auto;
#                 overflow-x: auto;
#                 border: 1px solid #ccc;
#                 padding: 15px;
#                 background-color: #f9f9f9;
#                 font-family: monospace;
#                 white-space: pre-wrap;
#                 word-wrap: break-word;">
#         Yes just arrived &nbsp; From: P66trans &lt;P66trans@chrobinson.com&gt; Sent: Thursday, April 2, 2026 2:17 PM To: Cambron, Rachel L &lt;Rachel.L.Cambron@p66.com&gt;; Justin Yow &lt;jyow@cadencepetroleum.com&gt;; Manuel Marin &lt;Manuel.Marin@chrobinson.com&gt;; GRP:HA Lubes--Dock Admin &lt;HALubesDockAdmin@p66.com&gt; Cc: GRP:HA Lubes--Scheduling &lt;HALubes--Scheduling@p66.com&gt;; Good, Zach L &lt;Zach.L.Good@p66.com&gt;; Krystal Sanders &lt;Krystal.Sanders@chrobinson.com&gt;; P66trans &lt;P66trans@chrobinson.com&gt; Subject: [EXTERNAL]RE: CHR orders for Gateway 4/2 ETA &nbsp; They should have just arrived. Are you able to confirm? Thank you, KEELAN D. LOWE Customer Account Specialist O: 405. 810. 7515 LOWEKEE@ chrobinson. com www. chrobinson. com 1601 Northwest Expy | Ste 620 | Oklahoma City, OK 73118 United States From: ZjQcmQRYFpfptBannerStart Caution: External Email This email originated from outside our organization. Please verify the sender's identity and exercise caution before clicking on any links or downloading attachments. Be wary of unexpected requests for sensitive information. If in doubt, click on the &quot;Report Suspicious&quot; button. &nbsp;&nbsp; &nbsp;&nbsp;Report&nbsp;Suspicious&nbsp;&nbsp; &nbsp;&nbsp;‌ ZjQcmQRYFpfptBannerEnd They should have just arrived. Are you able to confirm? &nbsp; Thank you, &nbsp; KEELAN D. LOWE Customer Account Specialist O: 405.810.7515 LOWEKEE@chrobinson.com www.chrobinson.com 1601 Northwest Expy | Ste 620 | Oklahoma City, OK 73118 United States &nbsp; From: P66trans &lt; P66trans@chrobinson.com &gt; Sent: Thursday, April 2, 2026 2:14 PM To: Cambron, Rachel L &lt; Rachel.L.Cambron@p66.com &gt;; Justin Yow &lt; jyow@cadencepetroleum.com &gt;; Manuel Marin &lt; Manuel.Marin@chrobinson.com &gt;; GRP:HA Lubes--Dock Admin &lt; HALubesDockAdmin@p66.com &gt; Cc: GRP:HA Lubes--Scheduling &lt; HALubes--Scheduling@p66.com &gt;; Good, Zach L &lt; zach.l.good@p66.com &gt;; Krystal Sanders &lt; Krystal.Sanders@chrobinson.com &gt;; P66trans &lt; P66trans@chrobinson.com &gt; Subject: RE: CHR orders for Gateway 4/2 ETA &nbsp; Good afternoon, &nbsp; ETA for this was 1400, reaching out to carrier now to confirm new ETA. &nbsp; Thank you, &nbsp; KEELAN D. LOWE Customer Account Specialist O: 405.810.7515 LOWEKEE@chrobinson.com www.chrobinson.com 1601 Northwest Expy | Ste 620 | Oklahoma City, OK 73118 United States &nbsp; From: Cambron, Rachel L &lt; Rachel.L.Cambron@p66.com &gt; Sent: Thursday, April 2, 2026 2:10 PM To: P66trans &lt; P66trans@chrobinson.com &gt;; Justin Yow &lt; jyow@cadencepetroleum.com &gt;; Manuel Marin &lt; Manuel.Marin@chrobinson.com &gt;; GRP:HA Lubes--Dock Admin &lt; HALubesDockAdmin@p66.com &gt; Cc: GRP:HA Lubes--Scheduling &lt; HALubes--Scheduling@p66.com &gt;; Good, Zach L &lt; zach.l.good@p66.com &gt;; Krystal Sanders &lt; Krystal.Sanders@chrobinson.com &gt; Subject: RE: CHR orders for Gateway 4/2 ETA &nbsp; eta&nbsp;&nbsp; please &nbsp; 5 to 7 Y 4529779698 877093744 RBTW MCKEES &nbsp; &nbsp; &nbsp; Gateway and Hartford plant will be closed Friday April 3rd &nbsp;in observance of Good Friday &nbsp; &nbsp; &nbsp; Thank you, &nbsp; Rachel Cambron Gateway Transportation Email Rachel.L.Cambron@p66.com Office:618-801-4943 &nbsp; &nbsp; &nbsp; &nbsp; From: P66trans &lt; P66trans@chrobinson.com &gt; Sent: Thursday, April 2, 2026 10:12 AM To: Cambron, Rachel L &lt; Rachel.L.Cambron@p66.com &gt;; Justin Yow &lt; jyow@cadencepetroleum.com &gt;; Manuel Marin &lt; Manuel.Marin@chrobinson.com &gt;; GRP:HA Lubes--Dock Admin &lt; HALubesDockAdmin@p66.com &gt; Cc: GRP:HA Lubes--Scheduling &lt; HALubes--Scheduling@p66.com &gt;; Good, Zach L &lt; Zach.L.Good@p66.com &gt;; Krystal Sanders &lt; Krystal.Sanders@chrobinson.com &gt;; P66trans &lt; P66trans@chrobinson.com &gt; Subject: [EXTERNAL]RE: CHR orders for Gateway 4/2 ETA &nbsp; Understood, working to get this secured with a carrier that can make pick first thing in the morning. Thank you, KEELAN D. LOWE Customer Account Spec ...

# %%
# df_enriched.drop(columns=['EMAIL_TEXT','EMAIL_TEXT_CLEAN']).to_csv('/home/azureuser/trackingContextBuilder/trackingContextBuilder/data/processed/enriched_matched_df.csv', index=False)

# %%
# crosswalk_df.head()

# %%
# crosswalk_df[crosswalk_df['LOADNUMBER']==552379931]

# %%
# df_enriched[df_enriched['CONVERSATION_ID']=='AAQkADg0NTdmMTQzLWFjYWItNDkwYy04OTE1LTcxMzljZjhmNGE5MQAQALwBCjos5EFopwpWoR3eAyw='][['CONVERSATION_ID','MESSAGE_ID','SUBJECT','EMAIL_TEXT_CLEAN']]

# %%
# # Search for a specific REFNUM value
# target_refnum = 'U'  # Replace with your actual value

# # Filter rows where target_refnum is in the REFNUMS array
# matching_rows = crosswalk_df[crosswalk_df['REFNUMS'].apply(lambda x: target_refnum in x if isinstance(x, list) else False)]

# print(f"Found {len(matching_rows)} records containing REFNUM: {target_refnum}")
# matching_rows

# %% [markdown]
# ### Apply Enhanced Enrichment (Subject + Body Extraction)
#
# Use the enhanced function to extract load identifiers from both subject lines AND email body text.

# %% [markdown]
# ### Analyze Enriched Results

# %%
# Example 1: Filter emails that have matches
emails_with_matches = df_enriched[df_enriched['match_count'] > 0]
print(f"📊 Emails with crosswalk matches: {len(emails_with_matches):,}")
print(f"\nSample matched emails:")
print(emails_with_matches[['SUBJECT', 'matched_refnums', 'loadnumbers', 'partycodes']].head())

print("\n" + "="*80 + "\n")

# Example 2: Filter emails for a specific partycode
if len(emails_with_matches) > 0 and len(emails_with_matches.iloc[0]['partycodes']) > 0:
    example_partycode = emails_with_matches.iloc[0]['partycodes'][0]
    emails_for_party = df_enriched[df_enriched['partycodes'].apply(lambda x: example_partycode in x)]
    print(f"📧 Emails for partycode {example_partycode}: {len(emails_for_party):,}")
    
print("\n" + "="*80 + "\n")

# Example 3: Filter emails for a specific load number
if len(emails_with_matches) > 0 and len(emails_with_matches.iloc[0]['loadnumbers']) > 0:
    example_loadnum = emails_with_matches.iloc[0]['loadnumbers'][0]
    emails_for_load = df_enriched[df_enriched['loadnumbers'].apply(lambda x: example_loadnum in x)]
    print(f"📦 Emails for load number {example_loadnum}: {len(emails_for_load):,}")
    print(emails_for_load[['SUBJECT', 'SENT_DATE', 'TIME_SENT_UTC']].head())

print("\n" + "="*80 + "\n")

# Example 4: Emails that didn't match
no_match = df_enriched[df_enriched['match_count'] == 0]
print(f"⚠️  Emails without matches: {len(no_match):,}")
if len(no_match) > 0:
    print("\nSample subjects without matches:")
    for i, subject in enumerate(no_match['SUBJECT'].head(5)):
        print(f"  {i+1}. {subject}")
# Out:
# 📊 Emails with crosswalk matches: 310,224
#
# Sample matched emails:
#                                            SUBJECT  \
# 0  回复： Re: 回复： Re: 回复： Re: 回复： 547005356 need ETa
# 2                           CH ROBINSON WEST 02-19
# 3                         Re: Driver ETA 244723172
# 5                     RE: Booked Load #: 548175887
# 7                                         RE: Ward
#
#                                      matched_refnums  \
# 0                                        [547005356]
# 2  [20423935, 20425744, 1721928888, 20426558, 172...
# 3  [610687981, 244723172, 610685801, 244677637, 1...
# 5        [20260408, 7000515259, 20260325, 548175887]
# 7                                           [128522]
#
#                                          loadnumbers  \
# 0                                        [547005356]
# 2  [551380877, 544491711, 543987652, 543927719, 5...
# 3                  [548491326, 547703515, 541573431]
# 5                  [552709477, 548175887, 553186203]
# 7                                        [541573431]
#
#                        partycodes
# 0                      [C7437122]
# 2            [C8291352, C6815012]
# 3            [C8908532, C7370298]
# 5  [C8797801, C8385842, C7025292]
# 7                      [C8908532]
#
# ================================================================================
#
# 📧 Emails for partycode C7437122: 1,160
#
# ================================================================================
#
# 📦 Emails for load number 547005356: 6
#                                                 SUBJECT   SENT_DATE  \
# 0       回复： Re: 回复： Re: 回复： Re: 回复： 547005356 need ETa   2026-03-19
# 210839          回复： Re: 回复： Re: 回复： 547005356 need ETa   2026-03-19
# 347813                  回复： Re: 回复： 547005356 need ETa   2026-03-19
# 358840                          回复： 547005356 need ETa   2026-03-19
# 359573                          回复： 547005356 need ETa   2026-03-19
#
#                     TIME_SENT_UTC
# 0      2026-03-19 20:22:18.314046
# 210839 2026-03-19 16:23:57.333998
# 347813 2026-03-19 16:20:01.688216
# 358840 2026-03-19 16:17:46.446918
# 359573 2026-03-19 16:15:23.662390
#
# ================================================================================
#
# ⚠️  Emails without matches: 184,093
#
# Sample subjects without matches:
#   1. RE: GKDRALA260763 RE: [INTERNAL]:RE: NEED BOL AND CARRIER - PU#'S  805403603, 805403601, 805403600, PO#'S 219752, 219565, 218844 - GKN DRIVELINE - MEBANE
#   2. RE: IMDL Loads 2/27
#   3. RE: anyone around today?
#   4. Re: Request for Pickup ETA - Load # 545573520 [#2098797]
#   5. RE: 04.01 NR (Rebecca - Honda) - ETA Req
# 📦 Emails for load number 547005356: 6
#                                                 SUBJECT   SENT_DATE  \
# 0       回复： Re: 回复： Re: 回复： Re: 回复： 547005356 need ETa   2026-03-19
# 210839          回复： Re: 回复： Re: 回复： 547005356 need ETa   2026-03-19
# 347813                  回复： Re: 回复： 547005356 need ETa   2026-03-19
# 358840                          回复： 547005356 need ETa   2026-03-19
# 359573                          回复： 547005356 need ETa   2026-03-19
#
#                     TIME_SENT_UTC
# 0      2026-03-19 20:22:18.314046
# 210839 2026-03-19 16:23:57.333998
# 347813 2026-03-19 16:20:01.688216
# 358840 2026-03-19 16:17:46.446918
# 359573 2026-03-19 16:15:23.662390
#
# ================================================================================
#
# ⚠️  Emails without matches: 184,093
#
# Sample subjects without matches:
#   1. RE: GKDRALA260763 RE: [INTERNAL]:RE: NEED BOL AND CARRIER - PU#'S  805403603, 805403601, 805403600, PO#'S 219752, 219565, 218844 - GKN DRIVELINE - MEBANE
#   2. RE: IMDL Loads 2/27
#   3. RE: anyone around today?
#   4. Re: Request for Pickup ETA - Load # 545573520 [#2098797]
#   5. RE: 04.01 NR (Rebecca - Honda) - ETA Req

# %%
df_enriched.columns
# Out:
# Index(['CONVERSATION_ID', 'MESSAGE_ID', 'SUBJECT', 'EMAIL_TEXT', 'SENDER',
#        'SENDER_DOMAIN', 'SENDER_IS_CHR', 'RECIPIENT', 'RECIPIENT_DOMAIN',
#        'RECIPIENT_IS_CHR', 'TIME_SENT_UTC', 'SENT_DATE', 'SENT_HOUR',
#        'TIME_RECEIVED_UTC', 'MAILBOXES', 'CLASSIFICATION', 'CATEGORIES',
#        'MONTHSTARTDATE', 'WORKDAYS', 'EMAIL_TEXT_CLEAN',
#        'extracted_ids_subject', 'extracted_ids_body', 'extracted_identifiers',
#        'matched_refnums', 'loadnumbers', 'partycodes', 'carrier_code',
#        'carrier_name', 'match_count', 'match_source'],
#       dtype='object')

# %%
matches_crosswalk = df_enriched[
    (df_enriched['partycodes'].notnull()) & 
    (df_enriched['partycodes'].apply(lambda x: len(x) > 0))
][['CONVERSATION_ID','loadnumbers','partycodes','carrier_code','carrier_name']].drop_duplicates(subset='CONVERSATION_ID', keep='first')
matches_crosswalk.shape
# Out:
# (112582, 5)

# %%
df_final = pd.merge(df_enriched, matches_crosswalk.add_suffix('_final'), how='left', left_on='CONVERSATION_ID', right_on='CONVERSATION_ID_final')
df_final.shape
# Out:
# (494317, 35)

# %%
matches_crosswalk[matches_crosswalk['CONVERSATION_ID']=='AAQkADcxNjMxYTgyLTc3NTYtNDdiYS1hMjYwLTJjZTAwYjZmZmZmNwAQAE797gsa2kF6lI0GjghCgLI=']
# Out:
#                                           CONVERSATION_ID  loadnumbers  \
# 373488  AAQkADcxNjMxYTgyLTc3NTYtNDdiYS1hMjYwLTJjZTAwYj...  [549883632]
#
#        partycodes carrier_code       carrier_name
# 373488  [C665729]     T3088892  A & I Express Inc

# %%
df_final.groupby('MESSAGE_ID').agg({'CONVERSATION_ID':'count'}).reset_index().sort_values(by='CONVERSATION_ID', ascending=False)
# Out:
#                                   MESSAGE_ID  CONVERSATION_ID
# 0       000025ed-795d-42e7-911c-d1770af4131e                1
# 329584  aac961cb-5db8-458c-959c-2bf0b7d0335a                1
# 329552  aac578c4-1fb1-4061-bd9c-36ac0232df71                1
# 329551  aac56375-a616-4f73-a364-faf9eefc89f6                1
# 329550  aac4fa98-3ae6-4c12-8922-fb8c3a38b02d                1
# ...                                      ...              ...
# 164769  5578b9ab-bf9d-4fe7-baef-287c6556a3c4                1
# 164768  5578ace3-62fe-4570-b24d-419d8f7abc84                1
# 164767  55788b5f-4ccf-479a-8a39-b828c4b3491f                1
# 164766  55786b1e-4f80-40cd-b815-8c568e10f381                1
# 494316  fffffbf4-09b1-4dbf-9e3d-f877706bebc3                1
#
# [494317 rows x 2 columns]

# %%
df_final[df_final['MESSAGE_ID']=='000099ee-7189-4a94-aeec-06d603a56210'].drop(columns=['EMAIL_TEXT']) #.to_csv('/home/azureuser/trackingContextBuilder/trackingContextBuilder/data/processed/tester.csv', index=False)
# Out:
#                                           CONVERSATION_ID  \
# 373488  AAQkADcxNjMxYTgyLTc3NTYtNDdiYS1hMjYwLTJjZTAwYj...
#
#                                   MESSAGE_ID      SUBJECT              SENDER  \
# 373488  000099ee-7189-4a94-aeec-06d603a56210  RE: 3174113  biolab@kikcorp.com
#
#        SENDER_DOMAIN  SENDER_IS_CHR  \
# 373488   kikcorp.com              0
#
#                                                 RECIPIENT  \
# 373488  [  "biolab@kikcorp.com",  "MUmali@kikcorp.com"...
#
#                             RECIPIENT_DOMAIN RECIPIENT_IS_CHR  \
# 373488  [  "kikcorp.com",  "chrobinson.com"]        [  0,  1]
#
#                     TIME_SENT_UTC  ... partycodes  carrier_code  \
# 373488 2026-04-14 21:16:10.452860  ...  [C665729]      T3088892
#
#              carrier_name match_count match_source  \
# 373488  A & I Express Inc           1      subject
#
#                                     CONVERSATION_ID_final loadnumbers_final  \
# 373488  AAQkADcxNjMxYTgyLTc3NTYtNDdiYS1hMjYwLTJjZTAwYj...       [549883632]
#
#         partycodes_final carrier_code_final carrier_name_final
# 373488         [C665729]           T3088892  A & I Express Inc
#
# [1 rows x 34 columns]

# %%
df_final = df_final.drop_duplicates(subset=['MESSAGE_ID'], keep='first')
df_final.shape
# Out:
# (494317, 35)

# %% [markdown]
# ### Final Match Summary

# %%
# Summary statistics for final matches
total_emails = len(df_final)

# Original match rate (before join with matches_crosswalk)
emails_with_original_match = df_enriched[
    (df_enriched['partycodes'].notnull()) & 
    (df_enriched['partycodes'].apply(lambda x: len(x) > 0))
]
num_original_matches = len(emails_with_original_match)
original_match_percentage = (num_original_matches / total_emails * 100) if total_emails > 0 else 0

# Final match rate (after join with matches_crosswalk)
emails_with_final_match = df_final[
    (df_final['partycodes_final'].notnull()) & 
    (df_final['partycodes_final'].apply(lambda x: len(x) > 0 if isinstance(x, list) else False))
]
num_emails_with_match = len(emails_with_final_match)
match_percentage = (num_emails_with_match / total_emails * 100) if total_emails > 0 else 0

print("="*80)
print("📊 FINAL MATCH SUMMARY")
print("="*80)
print(f"\nTotal emails in dataset: {total_emails:,}")

print(f"\n{'ORIGINAL MATCHES (df_enriched):':-^80}")
print(f"Emails with party code matches: {num_original_matches:,}")
print(f"Original match rate: {original_match_percentage:.2f}%")

print(f"\n{'FINAL MATCHES (df_final after join):':-^80}")
print(f"Emails with party code matches: {num_emails_with_match:,}")
print(f"Final match rate: {match_percentage:.2f}%")

print(f"\n{'COMPARISON:':-^80}")
if num_emails_with_match == num_original_matches:
    print(f"✓ Match rates are the same - no change from join")
else:
    diff = num_emails_with_match - num_original_matches
    diff_pct = match_percentage - original_match_percentage
    print(f"Change: {diff:+,} emails ({diff_pct:+.2f} percentage points)")

print(f"\nEmails without matches: {total_emails - num_emails_with_match:,} ({100 - match_percentage:.2f}%)")

# Count unique party codes and load numbers in final matches
if num_emails_with_match > 0:
    all_final_partycodes = set()
    all_final_loadnums = set()
    
    for _, row in emails_with_final_match.iterrows():
        if isinstance(row['partycodes_final'], list):
            all_final_partycodes.update(row['partycodes_final'])
        if isinstance(row['loadnumbers_final'], list):
            all_final_loadnums.update(row['loadnumbers_final'])
    
    print(f"\nUnique party codes identified: {len(all_final_partycodes):,}")
    print(f"Unique load numbers identified: {len(all_final_loadnums):,}")

print("="*80)
# Out:
# ================================================================================
# 📊 FINAL MATCH SUMMARY
# ================================================================================
#
# Total emails in dataset: 494,317
#
# ------------------------ORIGINAL MATCHES (df_enriched):-------------------------
# Emails with party code matches: 310,224
# Original match rate: 62.76%
#
# ----------------------FINAL MATCHES (df_final after join):----------------------
# Emails with party code matches: 322,663
# Final match rate: 65.27%
#
# ----------------------------------COMPARISON:-----------------------------------
# Change: +12,439 emails (+2.52 percentage points)
#
# Emails without matches: 171,654 (34.73%)
#
# Unique party codes identified: 7,109
# Unique load numbers identified: 151,119
# ================================================================================
#
# Unique party codes identified: 7,109
# Unique load numbers identified: 151,119
# ================================================================================

# %%
# Dropping initial email text column
df_final = df_final.drop(columns=['EMAIL_TEXT'])

# %%
df_final.columns
# Out:
# Index(['CONVERSATION_ID', 'MESSAGE_ID', 'SUBJECT', 'SENDER', 'SENDER_DOMAIN',
#        'SENDER_IS_CHR', 'RECIPIENT', 'RECIPIENT_DOMAIN', 'RECIPIENT_IS_CHR',
#        'TIME_SENT_UTC', 'SENT_DATE', 'SENT_HOUR', 'TIME_RECEIVED_UTC',
#        'MAILBOXES', 'CLASSIFICATION', 'CATEGORIES', 'MONTHSTARTDATE',
#        'WORKDAYS', 'EMAIL_TEXT_CLEAN', 'extracted_ids_subject',
#        'extracted_ids_body', 'extracted_identifiers', 'matched_refnums',
#        'loadnumbers', 'partycodes', 'carrier_code', 'carrier_name',
#        'match_count', 'match_source', 'CONVERSATION_ID_final',
#        'loadnumbers_final', 'partycodes_final', 'carrier_code_final',
#        'carrier_name_final'],
#       dtype='object')

# %% [markdown]
# ## 4. Filter Out Internal CHR Emails
#
# Remove emails where CHR is sending only to other CHR recipients (internal emails).
# Keep emails where:
# - SENDER_IS_CHR = 1 AND at least one recipient is external (RECIPIENT_IS_CHR contains 0)
# - OR SENDER_IS_CHR = 0 (external sender)

# %%
def filter_external_emails(df):
    """
    Filter out internal CHR emails (CHR sender to only CHR recipients).
    
    Keeps emails where:
    - SENDER_IS_CHR = 1 AND RECIPIENT_IS_CHR contains at least one 0 (external recipient)
    - OR SENDER_IS_CHR = 1 AND RECIPIENT_IS_CHR = [0] (only external recipients)
    - OR SENDER_IS_CHR = 0 (external sender - keep all regardless of recipients)
    
    Removes emails where:
    - SENDER_IS_CHR = 1 AND RECIPIENT_IS_CHR = [1] (only internal CHR recipients, no external)
    
    Args:
        df: DataFrame with SENDER_IS_CHR and RECIPIENT_IS_CHR columns
        
    Returns:
        Filtered DataFrame with internal CHR emails removed
    """
    import re
    
    original_count = len(df)
    
    def is_chr_only_recipients(recipient_str):
        """
        Check if RECIPIENT_IS_CHR array contains ONLY the value 1 (no 0s).
        
        The field is a string like "[  1]" or "[  0,  1]" or "[  0]"
        Returns True if the array contains only 1 (should be filtered out)
        Returns False if it contains 0 or both 0 and 1 (should be kept)
        """
        if pd.isna(recipient_str):
            return False
        
        # Convert string representation to actual values
        # Extract all digits from the string (ignoring brackets, spaces, commas)
        str_val = str(recipient_str)
        numbers = re.findall(r'\d+', str_val)
        
        if not numbers:
            return False
        
        # Convert to integers
        values = [int(n) for n in numbers]
        
        # Check if array contains ONLY 1 (no 0s)
        # If it contains only 1s and no 0s, return True (should filter)
        has_zero = 0 in values
        has_one = 1 in values
        
        # Return True if it has 1 but NOT 0 (chr only recipients)
        return has_one and not has_zero
    
    # Mask: Keep all emails EXCEPT those where sender is CHR AND recipients are CHR-only
    # In other words, remove rows where SENDER_IS_CHR=1 AND RECIPIENT_IS_CHR=[1]
    mask = ~(
        (df['SENDER_IS_CHR'] == 1) &  # CHR sender
        df['RECIPIENT_IS_CHR'].apply(is_chr_only_recipients)  # Only CHR recipients
    )
    
    df_filtered = df[mask].copy()
    
    removed_count = original_count - len(df_filtered)
    
    print("="*80)
    print("📧 INTERNAL EMAIL FILTERING")
    print("="*80)
    print(f"Original email count: {original_count:,}")
    print(f"Emails removed (CHR → only CHR recipients): {removed_count:,}")
    print(f"Emails remaining: {len(df_filtered):,}")
    print(f"Retention rate: {len(df_filtered)/original_count*100:.2f}%")
    print("="*80)
    
    return df_filtered

print("✅ Filter function created: filter_external_emails()")
# Out:
# ✅ Filter function created: filter_external_emails()

# %%
# df_final[df_final['SENDER_IS_CHR']==1]

# %%
# # Diagnostic: Check the actual values in RECIPIENT_IS_CHR column
# print("Sample RECIPIENT_IS_CHR values:")
# print("="*80)
# sample_chr_senders = df_final[df_final['SENDER_IS_CHR']==1].head(20)
# for idx, row in sample_chr_senders.iterrows():
#     print(f"SENDER_IS_CHR: {row['SENDER_IS_CHR']}")
#     print(f"RECIPIENT_IS_CHR: {row['RECIPIENT_IS_CHR']} (type: {type(row['RECIPIENT_IS_CHR'])})")
#     print(f"Is list: {isinstance(row['RECIPIENT_IS_CHR'], list)}")
#     if isinstance(row['RECIPIENT_IS_CHR'], list):
#         print(f"List contents: {row['RECIPIENT_IS_CHR']}")
#         print(f"Has 0? {0 in row['RECIPIENT_IS_CHR']}")
#         print(f"Has 1? {1 in row['RECIPIENT_IS_CHR']}")
#     print("-"*40)

# %%
# Apply the filter to remove internal CHR emails
df_final_filtered = filter_external_emails(df_final)

print(f"\n✅ Filtered dataframe created: df_final_filtered")
print(f"Shape: {df_final_filtered.shape}")
df_final_filtered.head()
# Out:
# ================================================================================
# 📧 INTERNAL EMAIL FILTERING
# ================================================================================
# Original email count: 494,317
# Emails removed (CHR → only CHR recipients): 28,145
# Emails remaining: 466,172
# Retention rate: 94.31%
# ================================================================================
#
# ✅ Filtered dataframe created: df_final_filtered
# Shape: (466172, 34)
#                                      CONVERSATION_ID  \
# 0  AAQkAGI1ZTM2ODMxLWI1NmYtNGM5OC05NjY1LTdhMDk2MW...
# 1  AAQkADI3YTc5NjQyLTI5OWQtNGI1ZC1hN2UzLThjZmNjNW...
# 2  AAQkADRmOGE2NjQyLWVjYmMtNGE0Ni1hOWEzLTIwMTQwYT...
# 3  AAQkAGMyNmY1NGI1LTdmOGItNDRjZC1iOWRjLTkzYzkzND...
# 4  AAQkADIzY2I2OTA3LWUzMGQtNDE0My05NjI3LTRjZjY5MW...
#
#                              MESSAGE_ID  \
# 0  5128cfe2-05a8-4344-84b6-68cd25d8b20d
# 1  3674a835-f09b-4cdd-876a-a180e3282fac
# 2  0db9b2ce-4f41-41ab-8743-c3e521f917ae
# 3  b5a4ed8e-82a0-428b-83df-ec9486d286f6
# 4  d0977b7b-c7d4-465c-baad-49dec9164fac
#
#                                              SUBJECT  \
# 0    回复： Re: 回复： Re: 回复： Re: 回复： 547005356 need ETa
# 1  RE: GKDRALA260763 RE: [INTERNAL]:RE: NEED BOL ...
# 2                             CH ROBINSON WEST 02-19
# 3                           Re: Driver ETA 244723172
# 4                                RE: IMDL Loads 2/27
#
#                            SENDER  SENDER_DOMAIN  SENDER_IS_CHR  \
# 0           pallogistic@yahoo.com      yahoo.com              0
# 1          jessica.wrobel@gxo.com        gxo.com              0
# 2           Ana.RLopez@ravago.com     ravago.com              0
# 3  Laura.Hernandez2@us.yazaki.com  us.yazaki.com              0
# 4      victoria.gatbunton@aldi.us        aldi.us              0
#
#                                            RECIPIENT  \
# 0               [  "Meliza.Baltazar@chrobinson.com"]
# 1  [  "Road.Driveline@gknautomotive.com",  "shell...
# 2  [  "chr-ravago@chrobinson.com",  "CHR-FL@chrob...
# 3  [  "Cinthya.Montes@brose.com",  "Deanna.Hojnac...
# 4  [  "intltmplanning@aldi.us",  "mike.fikis@aldi...
#
#                                     RECIPIENT_DOMAIN RECIPIENT_IS_CHR  \
# 0                               [  "chrobinson.com"]            [  1]
# 1  [  "gknautomotive.com",  "gxo.com",  "chrobins...        [  1,  0]
# 2                               [  "chrobinson.com"]            [  1]
# 3  [  "brose.com",  "chrobinson.com",  "us.yazaki...        [  0,  1]
# 4                   [  "aldi.us",  "chrobinson.com"]        [  1,  0]
#
#                TIME_SENT_UTC  ...            partycodes  carrier_code  \
# 0 2026-03-19 20:22:18.314046  ...            [C7437122]      T5176388
# 1 2026-03-24 13:29:37.626560  ...                    []          None
# 2 2026-02-19 13:57:42.967921  ...  [C8291352, C6815012]       T455318
# 3 2026-03-28 02:33:26.254735  ...  [C8908532, C7370298]      T3049246
# 4 2026-03-02 14:39:18.356985  ...                    []          None
#
#                        carrier_name match_count match_source  \
# 0                  Pal Logistic Inc           1         both
# 1                              None           0         None
# 2  American Furniture Warehouse Co.          14         body
# 3    POINT DEDICATED SERVICES, INC.           7         both
# 4                              None           0         None
#
#                                CONVERSATION_ID_final  \
# 0  AAQkAGI1ZTM2ODMxLWI1NmYtNGM5OC05NjY1LTdhMDk2MW...
# 1                                                NaN
# 2  AAQkADRmOGE2NjQyLWVjYmMtNGE0Ni1hOWEzLTIwMTQwYT...
# 3  AAQkAGMyNmY1NGI1LTdmOGItNDRjZC1iOWRjLTkzYzkzND...
# 4                                                NaN
#
#                                    loadnumbers_final      partycodes_final  \
# 0                                        [547005356]            [C7437122]
# 1                                                NaN                   NaN
# 2  [551380877, 544491711, 543987652, 543927719, 5...  [C8291352, C6815012]
# 3                  [548491326, 547703515, 541573431]  [C8908532, C7370298]
# 4                                                NaN                   NaN
#
#   carrier_code_final                carrier_name_final
# 0           T5176388                  Pal Logistic Inc
# 1                NaN                               NaN
# 2            T455318  American Furniture Warehouse Co.
# 3           T3049246    POINT DEDICATED SERVICES, INC.
# 4                NaN                               NaN
#
# [5 rows x 34 columns]

# %%
df_final_filtered[df_final_filtered['SENDER_IS_CHR']==1]
# Out:
#                                           CONVERSATION_ID  \
# 5       AAQkADEwYzc1MTljLWZjZmEtNGNhOS04YjExLWEwOWUwYW...
# 7       AAQkADlhYmRjYzQyLTUzZTItNGIzOC04NmU0LTczZGMyNz...
# 9       AAQkADhlMDNlNzMzLTVjNzYtNGU5NC1iYWM1LTZiMjgwYj...
# 10      AAQkADc5OTYyYzljLWFkZmUtNDJiZi1iOWEyLThlY2UzYz...
# 13      AAQkAGZhZmViNDQzLTU2NGQtNDMzYS1iMWQ4LWEwM2IxZT...
# ...                                                   ...
# 494291  AAQkADY2ZTU5MjBjLWQyMjEtNDk4Ni1hYjk0LWJkNGFmY2...
# 494294  AAQkADY2ZTU5MjBjLWQyMjEtNDk4Ni1hYjk0LWJkNGFmY2...
# 494297  AAQkAGVjZjBhNTg2LTEzZTgtNDY4Ni1iNTEzLTQ2NTNhOT...
# 494300  AAQkADhmYTljZTAwLWU2MzgtNGFkNy04ZDg0LWM4ZDgzMz...
# 494303  AAQkADNhM2I2N2EzLTU2ZDEtNDkyYi05YzIwLWJlMGMwZG...
#
#                                   MESSAGE_ID  \
# 5       ba103e0f-57c7-461c-84ef-be13928e8062
# 7       b0619335-ab46-48c6-a1dd-97972cdda1bb
# 9       d7a9ddeb-cbf8-49f3-bd1d-9246b5a405ad
# 10      0a4dbf9e-276d-4104-9fb3-52e224682981
# 13      c84dcff2-6268-4dca-a24f-40725c4bf92a
# ...                                      ...
# 494291  dcfed840-766f-40e3-9fd3-16ab1ed27705
# 494294  5b22a6ba-ad1a-4f15-80ca-930c4c6e4598
# 494297  cc9355c4-478b-438c-ad42-9a0f9aa2955e
# 494300  32b589e6-9f3f-4be2-88f9-767636905fc8
# 494303  6afa707a-1eaf-4335-9b04-76d090e26da4
#
#                                                   SUBJECT  \
# 5                            RE: Booked Load #: 548175887
# 7                                                RE: Ward
# 9                                               546925510
# 10               RE: 04.01 NR (Rebecca - Honda) - ETA Req
# 13      RE: Missed pickup/Flash Report PO# 0154461571 ...
# ...                                                   ...
# 494291                      CHRLoad# 551580312 &551581235
# 494294                                CHR Load# 549238052
# 494297             RE: Status request - 03/24 -  Facility
# 494300         RE: SID 13075144 - Scheduling/Ready Times?
# 494303                                  RE: TO-26412 ETA?
#
#                                  SENDER   SENDER_DOMAIN  SENDER_IS_CHR  \
# 5           ATSG-Tracing@chrobinson.com  chrobinson.com              1
# 7            Nathan.Leko@chrobinson.com  chrobinson.com              1
# 9        Kaitlin.Knutson@chrobinson.com  chrobinson.com              1
# 10      CHROperations250@chrobinson.com  chrobinson.com              1
# 13               WCD-All@chrobinson.com  chrobinson.com              1
# ...                                 ...             ...            ...
# 494291         USPS-Team@chrobinson.com  chrobinson.com              1
# 494294         USPS-Team@chrobinson.com  chrobinson.com              1
# 494297    BallOperations@chrobinson.com  chrobinson.com              1
# 494300               CNH@chrobinson.com  chrobinson.com              1
# 494303          Waterloo@chrobinson.com  chrobinson.com              1
#
#                                                 RECIPIENT  \
# 5       [  "ad@mdnfreightinc.com",  "tracking@mdnfreig...
# 7       [  "Jordan.Schockling@chrobinson.com",  "kschm...
# 9       [  "mcornelio@timelinktpn.com",  "Nick.Collins...
# 10      [  "Jacob.Lobodzinski@chrobinson.com",  "CHROp...
# 13      [  "Amanda.Smith@chrobinson.com",  "wcdlredsci...
# ...                                                   ...
# 494291  [  "after@bonanzacarriers.com",  "bonanzacarri...
# 494294                      [  "jabowexpedite@gmail.com"]
# 494297  [  "BallOperations@chrobinson.com",  "Ball@chr...
# 494300  [  "CNH@chrobinson.com",  "cameron.straw@cnh.c...
# 494303  [  "tiffany@drinkwaterloo.com",  "cc@drinkwate...
#
#                                          RECIPIENT_DOMAIN RECIPIENT_IS_CHR  \
# 5                                 [  "mdnfreightinc.com"]            [  0]
# 7                      [  "henry.com",  "chrobinson.com"]        [  1,  0]
# 9                [  "timelinktpn.com",  "chrobinson.com"]        [  0,  1]
# 10                  [  "chrobinson.com",  "michauto.com"]        [  0,  1]
# 13                    [  "chrobinson.com",  "wcdinc.net"]        [  0,  1]
# ...                                                   ...              ...
# 494291            [  "bonanzacarriers.com",  "gmail.com"]            [  0]
# 494294                                    [  "gmail.com"]            [  0]
# 494297        [  "chrobinson.com",  "wisetechglobal.com"]        [  0,  1]
# 494300  [  "cnh.com",  "chrobinson.com",  "ludlowmfg.c...        [  1,  0]
# 494303  [  "drinkwaterloo.com",  "mannabev.com",  "chr...        [  0,  1]
#
#                     TIME_SENT_UTC  ...                      partycodes  \
# 5      2026-03-30 12:27:40.995033  ...  [C8797801, C8385842, C7025292]
# 7      2026-03-11 19:56:26.688876  ...                      [C8908532]
# 9      2026-03-13 21:59:43.197496  ...                      [C8179725]
# 10     2026-04-02 16:21:43.661209  ...                              []
# 13     2026-03-10 18:27:11.679797  ...                      [C8242513]
# ...                           ...  ...                             ...
# 494291 2026-05-09 03:09:30.555450  ...            [C8910214, C7134670]
# 494294 2026-04-18 00:08:21.812764  ...            [C8910214, C7134670]
# 494297 2026-03-24 16:24:19.255218  ...                      [C8839725]
# 494300 2026-04-16 20:00:39.652243  ...                      [C2623715]
# 494303 2026-03-30 19:16:24.884659  ...                              []
#
#         carrier_code                               carrier_name match_count  \
# 5           T6142406                       LEGROS TRANSPORT LLC           4
# 7           T5002636  Transportes Rivera Gonzalez, S.A. de C.V.           1
# 9           T6315938                TIMELINK TRANSPORTATION LLC           1
# 10              None                                       None           0
# 13          T5148829                   Wheel King Transhaul Inc           2
# ...              ...                                        ...         ...
# 494291      T6126887                       BONANZA CARRIERS LLC           3
# 494294      T6100219                         JABOW EXPEDITE LLC           2
# 494297      T6012585              MIDWEST TRANSPORT EXPRESS INC           9
# 494300      T5184579                            Fox Freight Inc           1
# 494303          None                                       None           0
#
#        match_source                              CONVERSATION_ID_final  \
# 5              both  AAQkADEwYzc1MTljLWZjZmEtNGNhOS04YjExLWEwOWUwYW...
# 7              body  AAQkADlhYmRjYzQyLTUzZTItNGIzOC04NmU0LTczZGMyNz...
# 9           subject  AAQkADhlMDNlNzMzLTVjNzYtNGU5NC1iYWM1LTZiMjgwYj...
# 10             None                                                NaN
# 13             both  AAQkAGZhZmViNDQzLTU2NGQtNDMzYS1iMWQ4LWEwM2IxZT...
# ...             ...                                                ...
# 494291         both  AAQkADY2ZTU5MjBjLWQyMjEtNDk4Ni1hYjk0LWJkNGFmY2...
# 494294         both  AAQkADY2ZTU5MjBjLWQyMjEtNDk4Ni1hYjk0LWJkNGFmY2...
# 494297         body  AAQkAGVjZjBhNTg2LTEzZTgtNDY4Ni1iNTEzLTQ2NTNhOT...
# 494300         both  AAQkADhmYTljZTAwLWU2MzgtNGFkNy04ZDg0LWM4ZDgzMz...
# 494303         None                                                NaN
#
#                                         loadnumbers_final  \
# 5                       [552709477, 548175887, 553186203]
# 7                                             [541573431]
# 9                                             [546925510]
# 10                                                    NaN
# 13                                            [542079910]
# ...                                                   ...
# 494291                  [551581235, 551222902, 551580312]
# 494294                             [549238052, 551222902]
# 494297  [546961809, 546961808, 546807700, 546961812, 5...
# 494300                                        [550214451]
# 494303                                                NaN
#
#                       partycodes_final carrier_code_final  \
# 5       [C8797801, C8385842, C7025292]           T6142406
# 7                           [C8908532]           T5002636
# 9                           [C8179725]           T6315938
# 10                                 NaN                NaN
# 13                          [C8242513]           T5148829
# ...                                ...                ...
# 494291            [C8910214, C7134670]           T6126887
# 494294            [C8910214, C7134670]           T6100219
# 494297                      [C8839725]           T6012585
# 494300                      [C2623715]           T5184579
# 494303                             NaN                NaN
#
#                                carrier_name_final
# 5                            LEGROS TRANSPORT LLC
# 7       Transportes Rivera Gonzalez, S.A. de C.V.
# 9                     TIMELINK TRANSPORTATION LLC
# 10                                            NaN
# 13                       Wheel King Transhaul Inc
# ...                                           ...
# 494291                       BONANZA CARRIERS LLC
# 494294                         JABOW EXPEDITE LLC
# 494297              MIDWEST TRANSPORT EXPRESS INC
# 494300                            Fox Freight Inc
# 494303                                        NaN
#
# [105154 rows x 34 columns]

# %%
def filter_chr_senders_only(df):
    """
    Filter to keep only emails sent by CHR domain senders.
    
    Keeps emails where:
    - SENDER_IS_CHR = 1 (CHR sender)
    
    Removes emails where:
    - SENDER_IS_CHR = 0 (non-CHR sender)
    
    Args:
        df: DataFrame with SENDER_IS_CHR column
        
    Returns:
        Filtered DataFrame with only CHR sender emails
    """
    original_count = len(df)
    
    # Keep only emails where sender is CHR (SENDER_IS_CHR = 1)
    df_filtered = df[df['SENDER_IS_CHR'] == 1].copy()
    
    removed_count = original_count - len(df_filtered)
    
    print("="*80)
    print("📧 CHR SENDER FILTERING")
    print("="*80)
    print(f"Original email count: {original_count:,}")
    print(f"Emails removed (non-CHR senders): {removed_count:,}")
    print(f"Emails remaining (CHR senders only): {len(df_filtered):,}")
    print(f"Retention rate: {len(df_filtered)/original_count*100:.2f}%")
    print("="*80)
    
    return df_filtered

print("✅ Filter function created: filter_chr_senders_only()")
# Out:
# ✅ Filter function created: filter_chr_senders_only()

# %%
# Apply the filter to keep only CHR sender emails
df_final_chr_only = filter_chr_senders_only(df_final_filtered)

print(f"\n✅ CHR-only sender dataframe created: df_final_chr_only")
print(f"Shape: {df_final_chr_only.shape}")

# Show filtering progression statistics
print(f"\n{'='*80}")
print(f"📊 FILTERING PROGRESSION SUMMARY")
print(f"{'='*80}")
print(f"Starting dataset (df_final): {len(df_final):,} emails")
print(f"After filter 1 (remove internal CHR emails): {len(df_final_filtered):,} emails")
print(f"  └─ Removed: {len(df_final) - len(df_final_filtered):,} emails ({(len(df_final) - len(df_final_filtered))/len(df_final)*100:.2f}%)")
print(f"\nAfter filter 2 (keep only CHR senders): {len(df_final_chr_only):,} emails")
print(f"  └─ Removed: {len(df_final_filtered) - len(df_final_chr_only):,} emails ({(len(df_final_filtered) - len(df_final_chr_only))/len(df_final_filtered)*100:.2f}%)")
print(f"\n{'TOTAL FILTERING IMPACT:':-^80}")
print(f"Original emails: {len(df_final):,}")
print(f"Final emails: {len(df_final_chr_only):,}")
print(f"Total removed: {len(df_final) - len(df_final_chr_only):,} emails ({(len(df_final) - len(df_final_chr_only))/len(df_final)*100:.2f}%)")
print(f"Retention rate: {len(df_final_chr_only)/len(df_final)*100:.2f}%")
print(f"{'='*80}")

df_final_chr_only.head()
# Out:
# ================================================================================
# 📧 CHR SENDER FILTERING
# ================================================================================
# Original email count: 466,172
# Emails removed (non-CHR senders): 361,018
# Emails remaining (CHR senders only): 105,154
# Retention rate: 22.56%
# ================================================================================
#
# ✅ CHR-only sender dataframe created: df_final_chr_only
# Shape: (105154, 34)
#
# ================================================================================
# 📊 FILTERING PROGRESSION SUMMARY
# ================================================================================
# Starting dataset (df_final): 494,317 emails
# After filter 1 (remove internal CHR emails): 466,172 emails
#   └─ Removed: 28,145 emails (5.69%)
#
# After filter 2 (keep only CHR senders): 105,154 emails
#   └─ Removed: 361,018 emails (77.44%)
#
# ----------------------------TOTAL FILTERING IMPACT:-----------------------------
# Original emails: 494,317
# Final emails: 105,154
# Total removed: 389,163 emails (78.73%)
# Retention rate: 21.27%
# ================================================================================
#                                       CONVERSATION_ID  \
# 5   AAQkADEwYzc1MTljLWZjZmEtNGNhOS04YjExLWEwOWUwYW...
# 7   AAQkADlhYmRjYzQyLTUzZTItNGIzOC04NmU0LTczZGMyNz...
# 9   AAQkADhlMDNlNzMzLTVjNzYtNGU5NC1iYWM1LTZiMjgwYj...
# 10  AAQkADc5OTYyYzljLWFkZmUtNDJiZi1iOWEyLThlY2UzYz...
# 13  AAQkAGZhZmViNDQzLTU2NGQtNDMzYS1iMWQ4LWEwM2IxZT...
#
#                               MESSAGE_ID  \
# 5   ba103e0f-57c7-461c-84ef-be13928e8062
# 7   b0619335-ab46-48c6-a1dd-97972cdda1bb
# 9   d7a9ddeb-cbf8-49f3-bd1d-9246b5a405ad
# 10  0a4dbf9e-276d-4104-9fb3-52e224682981
# 13  c84dcff2-6268-4dca-a24f-40725c4bf92a
#
#                                               SUBJECT  \
# 5                        RE: Booked Load #: 548175887
# 7                                            RE: Ward
# 9                                           546925510
# 10           RE: 04.01 NR (Rebecca - Honda) - ETA Req
# 13  RE: Missed pickup/Flash Report PO# 0154461571 ...
#
#                              SENDER   SENDER_DOMAIN  SENDER_IS_CHR  \
# 5       ATSG-Tracing@chrobinson.com  chrobinson.com              1
# 7        Nathan.Leko@chrobinson.com  chrobinson.com              1
# 9    Kaitlin.Knutson@chrobinson.com  chrobinson.com              1
# 10  CHROperations250@chrobinson.com  chrobinson.com              1
# 13           WCD-All@chrobinson.com  chrobinson.com              1
#
#                                             RECIPIENT  \
# 5   [  "ad@mdnfreightinc.com",  "tracking@mdnfreig...
# 7   [  "Jordan.Schockling@chrobinson.com",  "kschm...
# 9   [  "mcornelio@timelinktpn.com",  "Nick.Collins...
# 10  [  "Jacob.Lobodzinski@chrobinson.com",  "CHROp...
# 13  [  "Amanda.Smith@chrobinson.com",  "wcdlredsci...
#
#                             RECIPIENT_DOMAIN RECIPIENT_IS_CHR  \
# 5                    [  "mdnfreightinc.com"]            [  0]
# 7         [  "henry.com",  "chrobinson.com"]        [  1,  0]
# 9   [  "timelinktpn.com",  "chrobinson.com"]        [  0,  1]
# 10     [  "chrobinson.com",  "michauto.com"]        [  0,  1]
# 13       [  "chrobinson.com",  "wcdinc.net"]        [  0,  1]
#
#                 TIME_SENT_UTC  ...                      partycodes  \
# 5  2026-03-30 12:27:40.995033  ...  [C8797801, C8385842, C7025292]
# 7  2026-03-11 19:56:26.688876  ...                      [C8908532]
# 9  2026-03-13 21:59:43.197496  ...                      [C8179725]
# 10 2026-04-02 16:21:43.661209  ...                              []
# 13 2026-03-10 18:27:11.679797  ...                      [C8242513]
#
#     carrier_code                               carrier_name match_count  \
# 5       T6142406                       LEGROS TRANSPORT LLC           4
# 7       T5002636  Transportes Rivera Gonzalez, S.A. de C.V.           1
# 9       T6315938                TIMELINK TRANSPORTATION LLC           1
# 10          None                                       None           0
# 13      T5148829                   Wheel King Transhaul Inc           2
#
#    match_source                              CONVERSATION_ID_final  \
# 5          both  AAQkADEwYzc1MTljLWZjZmEtNGNhOS04YjExLWEwOWUwYW...
# 7          body  AAQkADlhYmRjYzQyLTUzZTItNGIzOC04NmU0LTczZGMyNz...
# 9       subject  AAQkADhlMDNlNzMzLTVjNzYtNGU5NC1iYWM1LTZiMjgwYj...
# 10         None                                                NaN
# 13         both  AAQkAGZhZmViNDQzLTU2NGQtNDMzYS1iMWQ4LWEwM2IxZT...
#
#                     loadnumbers_final                partycodes_final  \
# 5   [552709477, 548175887, 553186203]  [C8797801, C8385842, C7025292]
# 7                         [541573431]                      [C8908532]
# 9                         [546925510]                      [C8179725]
# 10                                NaN                             NaN
# 13                        [542079910]                      [C8242513]
#
#    carrier_code_final                         carrier_name_final
# 5            T6142406                       LEGROS TRANSPORT LLC
# 7            T5002636  Transportes Rivera Gonzalez, S.A. de C.V.
# 9            T6315938                TIMELINK TRANSPORTATION LLC
# 10                NaN                                        NaN
# 13           T5148829                   Wheel King Transhaul Inc
#
# [5 rows x 34 columns]

# %% [markdown]
# ## 5. Analyze Non-CHR Email Recipients by Carrier and Partycode
#
# Analyze which external email addresses each carrier communicates with and the distribution of emails sent to each recipient, grouped by customer (partycode). This shows whether different carrier contacts are used for different customers.

# %%
def analyze_carrier_recipients(df):
    """
    Analyze non-CHR email recipients by carrier code and partycode.
    
    For each carrier-partycode combination, this function:
    1. Extracts all recipient email addresses from the RECIPIENT field
    2. Filters to only non-CHR emails (not ending in @chrobinson.com)
    3. Calculates the percentage of emails sent to each non-CHR recipient
    
    This shows which carrier contacts CHR uses for different customers (partycodes).
    
    Args:
        df: DataFrame with CARRIER_CODE, PARTYCODES_FINAL, and RECIPIENT columns
        
    Returns:
        DataFrame with columns:
        - carrier_code: The carrier code
        - carrier_name: Carrier name
        - partycode: The customer partycode
        - non_chr_recipients: Array of non-CHR email addresses
        - recipient_percentages: Array of percentages (corresponding to non_chr_recipients)
        - total_non_chr_emails: Total number of non-CHR email instances
        - unique_recipients: Count of unique non-CHR recipients
    """
    import re
    from collections import Counter
    
    def extract_non_chr_emails(recipient_field):
        """Extract non-CHR email addresses from the RECIPIENT field."""
        if pd.isna(recipient_field) or recipient_field == '':
            return []
        
        # Extract all email addresses using regex
        email_pattern = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b'
        emails = re.findall(email_pattern, str(recipient_field))
        
        # Filter to only non-CHR emails (not ending in @chrobinson.com)
        non_chr_emails = [
            email.lower() for email in emails 
            if not email.lower().endswith('@chrobinson.com')
        ]
        
        return non_chr_emails
    
    def get_partycode_string(partycodes_final):
        """Convert partycodes_final to a string representation."""
        if pd.isna(partycodes_final):
            return 'NO_PARTYCODE'
        if isinstance(partycodes_final, list):
            if len(partycodes_final) == 0:
                return 'NO_PARTYCODE'
            # Sort and join for consistent representation
            return ','.join(sorted([str(pc) for pc in partycodes_final]))
        return str(partycodes_final)
    
    # Filter to only rows with carrier_code
    df_with_carrier = df[df['carrier_code'].notna()].copy()
    
    # Create partycode string column for grouping
    df_with_carrier['partycode_str'] = df_with_carrier['partycodes_final'].apply(get_partycode_string)
    
    print("="*80)
    print("📊 ANALYZING NON-CHR RECIPIENTS BY CARRIER AND PARTYCODE")
    print("="*80)
    print(f"Total emails with carrier code: {len(df_with_carrier):,}")
    print(f"Processing recipient email extraction...")
    print("="*80 + "\n")
    
    # Group by carrier_code AND partycode_str and analyze recipients
    results = []
    
    for (carrier_code, partycode_str), group in df_with_carrier.groupby(['carrier_code', 'partycode_str']):
        # Get carrier_name (should be the same for all rows in group)
        carrier_name = group['carrier_name'].iloc[0] if 'carrier_name' in group.columns else None
        
        # Count all non-CHR emails for this carrier-partycode combination
        all_non_chr_emails = []
        
        for _, row in group.iterrows():
            non_chr_emails = extract_non_chr_emails(row['RECIPIENT'])
            all_non_chr_emails.extend(non_chr_emails)
        
        if len(all_non_chr_emails) == 0:
            # No non-CHR recipients for this carrier-partycode combination
            continue
        
        # Count occurrences of each email
        email_counts = Counter(all_non_chr_emails)
        total_emails = len(all_non_chr_emails)
        
        # Sort by count (descending) to get most common recipients first
        sorted_emails = sorted(email_counts.items(), key=lambda x: x[1], reverse=True)
        
        # Extract emails and percentages in the same order
        non_chr_recipients = [email for email, count in sorted_emails]
        recipient_percentages = [
            round((count / total_emails) * 100, 2) 
            for email, count in sorted_emails
        ]
        
        results.append({
            'carrier_code': carrier_code,
            'carrier_name': carrier_name,
            'partycode': partycode_str,
            'non_chr_recipients': non_chr_recipients,
            'recipient_percentages': recipient_percentages,
            'total_non_chr_emails': total_emails,
            'unique_recipients': len(non_chr_recipients)
        })
    
    # Create result dataframe
    result_df = pd.DataFrame(results)
    
    # Sort by total_non_chr_emails descending
    result_df = result_df.sort_values('total_non_chr_emails', ascending=False).reset_index(drop=True)
    
    print("\n" + "="*80)
    print("📈 ANALYSIS SUMMARY")
    print("="*80)
    print(f"Carrier-Partycode combinations with non-CHR recipients: {len(result_df):,}")
    print(f"Total non-CHR email instances analyzed: {result_df['total_non_chr_emails'].sum():,}")
    print(f"\nTop 5 carrier-partycode combinations by non-CHR email volume:")
    for i, row in result_df.head().iterrows():
        carrier_display = f"{row['carrier_code']}"
        if pd.notna(row.get('carrier_name')):
            carrier_display += f" ({row['carrier_name']})"
        partycode_display = f" - Partycode: {row['partycode']}"
        print(f"  {i+1}. {carrier_display}{partycode_display}: {row['total_non_chr_emails']:,} emails to {row['unique_recipients']} unique recipients")
    print("="*80)
    
    return result_df

print("✅ Carrier recipient analysis function created: analyze_carrier_recipients()")
# Out:
# ✅ Carrier recipient analysis function created: analyze_carrier_recipients()

# %%
# Analyze non-CHR recipients by carrier and partycode
carrier_recipients_df = analyze_carrier_recipients(df_final_chr_only)

print(f"\n✅ Analysis complete!")
print(f"\nResult dataframe columns:")
print(f"  - carrier_code: Carrier identifier")
print(f"  - carrier_name: Carrier name")
print(f"  - partycode: Customer partycode(s)")
print(f"  - non_chr_recipients: Array of non-CHR email addresses (sorted by frequency)")
print(f"  - recipient_percentages: Percentage of emails to each recipient (same order)")
print(f"  - total_non_chr_emails: Total number of non-CHR email instances")
print(f"  - unique_recipients: Count of unique non-CHR recipients")

carrier_recipients_df.head()
# Out:
# ================================================================================
# 📊 ANALYZING NON-CHR RECIPIENTS BY CARRIER
# ================================================================================
# Total emails with carrier code: 289,094
# Processing recipient email extraction...
# ================================================================================
#
#
# ================================================================================
# 📈 ANALYSIS SUMMARY
# ================================================================================
# Carriers with non-CHR recipients: 10,392
# Total non-CHR email instances analyzed: 437,786
#
# Top 5 carriers by non-CHR email volume:
#   1. T5002636 (Transportes Rivera Gonzalez, S.A. de C.V.): 25,672 emails to 8617 unique recipients
#   2. T6052965 (Roelcainc SA de CV): 6,659 emails to 1795 unique recipients
#   3. T6223436 (10511277 CANADA INC): 6,087 emails to 193 unique recipients
#   4. T191369 (Werner Enterprises, Inc.  ( Dedicated)): 5,732 emails to 282 unique recipients
#   5. T2081243 (ROBERT L GAST INC): 4,797 emails to 711 unique recipients
# ================================================================================
#
# ✅ Analysis complete!
#
# Result dataframe columns:
#   - carrier_code: Carrier identifier
#   - carrier_name: Carrier name
#   - non_chr_recipients: Array of non-CHR email addresses (sorted by frequency)
#   - recipient_percentages: Percentage of emails to each recipient (same order)
#   - total_non_chr_emails: Total number of non-CHR email instances
#   - unique_recipients: Count of unique non-CHR recipients
#
# ================================================================================
# 📈 ANALYSIS SUMMARY
# ================================================================================
# Carriers with non-CHR recipients: 10,392
# Total non-CHR email instances analyzed: 437,786
#
# Top 5 carriers by non-CHR email volume:
#   1. T5002636 (Transportes Rivera Gonzalez, S.A. de C.V.): 25,672 emails to 8617 unique recipients
#   2. T6052965 (Roelcainc SA de CV): 6,659 emails to 1795 unique recipients
#   3. T6223436 (10511277 CANADA INC): 6,087 emails to 193 unique recipients
#   4. T191369 (Werner Enterprises, Inc.  ( Dedicated)): 5,732 emails to 282 unique recipients
#   5. T2081243 (ROBERT L GAST INC): 4,797 emails to 711 unique recipients
# ================================================================================
#
# ✅ Analysis complete!
#
# Result dataframe columns:
#   - carrier_code: Carrier identifier
#   - carrier_name: Carrier name
#   - non_chr_recipients: Array of non-CHR email addresses (sorted by frequency)
#   - recipient_percentages: Percentage of emails to each recipient (same order)
#   - total_non_chr_emails: Total number of non-CHR email instances
#   - unique_recipients: Count of unique non-CHR recipients
#   carrier_code                               carrier_name  \
# 0     T5002636  Transportes Rivera Gonzalez, S.A. de C.V.
# 1     T6052965                         Roelcainc SA de CV
# 2     T6223436                        10511277 CANADA INC
# 3      T191369     Werner Enterprises, Inc.  ( Dedicated)
# 4     T2081243                          ROBERT L GAST INC
#
#                                   non_chr_recipients  \
# 0  [jcartia@peltonshepherd.com, operations@easyfl...
# 1  [rgill@alf-inc.com, emquantixlogistics@celanes...
# 2  [mandeep.kaur@greyexpress.ca, anmolpreet.kaur@...
# 3  [optimizationah@werner.com, austin.woerdehoff@...
# 4  [chrtracking@superegoholding.net, dispatch@rob...
#
#                                recipient_percentages  total_non_chr_emails  \
# 0  [0.27, 0.23, 0.22, 0.21, 0.17, 0.15, 0.14, 0.1...                 25672
# 1  [0.9, 0.89, 0.83, 0.78, 0.78, 0.77, 0.75, 0.74...                  6659
# 2  [9.61, 5.13, 4.55, 4.24, 3.96, 3.84, 3.63, 3.6...                  6087
# 3  [19.78, 11.78, 9.58, 9.37, 2.74, 2.04, 1.78, 1...                  5732
# 4  [12.4, 10.53, 5.69, 4.71, 2.52, 1.69, 1.63, 1....                  4797
#
#    unique_recipients
# 0               8617
# 1               1795
# 2                193
# 3                282
# 4                711

# %% [markdown]
# ### Example: View Top Recipients for a Specific Carrier-Partycode Combination
#
# Let's examine the distribution of recipients for one carrier-partycode combination in detail.

# %%
# Example: View details for the carrier with the most non-CHR emails
if len(carrier_recipients_df) > 0:
    top_carrier = carrier_recipients_df.iloc[0]
    
    print("="*80)
    carrier_display = f"📧 CARRIER: {top_carrier['carrier_code']}"
    if pd.notna(top_carrier.get('carrier_name')):
        carrier_display += f" ({top_carrier['carrier_name']})"
    carrier_display += f" | PARTYCODE: {top_carrier['partycode']}"
    print(carrier_display)
    print("="*80)
    print(f"Total non-CHR emails: {top_carrier['total_non_chr_emails']:,}")
    print(f"Unique recipients: {top_carrier['unique_recipients']}")
    print(f"\nTop 10 Recipients (sorted by percentage):")
    print("-"*80)
    
    for i, (email, pct) in enumerate(zip(
        top_carrier['non_chr_recipients'][:10], 
        top_carrier['recipient_percentages'][:10]
    ), 1):
        print(f"{i:2d}. {email:50s} {pct:6.2f}%")
    
    print("="*80)
else:
    print("No carriers with non-CHR recipients found.")
# Out:
# ================================================================================
# 📧 CARRIER: T5002636 (Transportes Rivera Gonzalez, S.A. de C.V.)
# ================================================================================
# Total non-CHR emails: 25,672
# Unique recipients: 8617
#
# Top 10 Recipients (sorted by percentage):
# --------------------------------------------------------------------------------
#  1. jcartia@peltonshepherd.com                           0.27%
#  2. operations@easyflyers.com                            0.23%
#  3. mexops@easyflyers.com                                0.22%
#  4. samantha.villarreal@easyflyers.com                   0.21%
#  5. alondra@valera.com.mx                                0.17%
#  6. mafer.zamora@easyflyers.com                          0.15%
#  7. molly.badrudeen@easyflyers.com                       0.14%
#  8. exportacionldo@cabrerallamas.com                     0.14%
#  9. chb@cabrerallamas.com                                0.14%
# 10. ninian@hmdtransport.com                              0.14%
# ================================================================================

# %% [markdown]
# ### Identify Carriers with High Email Concentration
#
# Sort carriers by the percentage of emails going to their top recipient to find carriers that send most emails to a single inbox.

# %%
# Sort carriers by the percentage going to their top recipient (first value in recipient_percentages)
# This shows carriers with high email concentration to a single inbox

carrier_recipients_sorted = carrier_recipients_df.copy()

# Extract the first percentage (top recipient percentage) for sorting
carrier_recipients_sorted['top_recipient_pct'] = carrier_recipients_sorted['recipient_percentages'].apply(
    lambda x: x[0] if isinstance(x, list) and len(x) > 0 else 0
)

# Sort by top recipient percentage descending
carrier_recipients_sorted = carrier_recipients_sorted.sort_values('top_recipient_pct', ascending=False).reset_index(drop=True)

print("="*80)
print("📊 CARRIERS SORTED BY EMAIL CONCENTRATION TO TOP RECIPIENT")
print("="*80)
print(f"Total carriers analyzed: {len(carrier_recipients_sorted):,}\n")
print("Top 20 carriers with highest concentration to single recipient:")
print("-"*80)
print(f"{'#':<4} {'Carrier':<15} {'Carrier Name':<25} {'Top %':<8} {'Top Recipient Email':<30}")
print("-"*80)

for i, row in carrier_recipients_sorted.head(20).iterrows():
    carrier = str(row['carrier_code'])[:14]  # Truncate if too long
    carrier_name = str(row.get('carrier_name', ''))[:24] if pd.notna(row.get('carrier_name')) else ''
    top_pct = row['top_recipient_pct']
    top_email = row['non_chr_recipients'][0] if len(row['non_chr_recipients']) > 0 else 'N/A'
    top_email_display = top_email[:29] if len(top_email) > 29 else top_email
    
    print(f"{i+1:<4} {carrier:<15} {carrier_name:<25} {top_pct:>6.2f}%  {top_email_display}")

print("="*80)

# Display the full dataframe sorted
carrier_recipients_sorted
# Out:
# ================================================================================
# 📊 CARRIERS SORTED BY EMAIL CONCENTRATION TO TOP RECIPIENT
# ================================================================================
# Total carriers analyzed: 10,392
#
# Top 20 carriers with highest concentration to single recipient:
# --------------------------------------------------------------------------------
# #    Carrier         Carrier Name              Top %    Top Recipient Email
# --------------------------------------------------------------------------------
# 1    T6018513        SKY HIGH TRANS INC        100.00%  hersheysalty@uberfreight.com
# 2    T2750821        MOUNTAIN EXPRESS, INC.    100.00%  amyw@stoltzfusfeed.com
# 3    T5323447        INPAX SHIPPING SOLUTIONS  100.00%  rmckie@shipinpax.com
# 4    T6000602        URBAN LOGISTICS LLC       100.00%  urban.logisticsllc@gmail.com
# 5    T6106054        DOUBLE H CONTRACTORS INC  100.00%  tammy.jones@kohler.com
# 6    T5147895        North Star Freight LLC    100.00%  inbound.logistics@jacklinks.c
# 7    T6314615        JB BROTHERS EXPRESS LLC   100.00%  cokeeastmwtmc@coca-cola.com
# 8    T4593042        Morpol Transit Inc        100.00%  fdcrec@tractorsupply.com
# 9    T6317455        Power + (DEADHEAD TRUCKI  100.00%  oscar@deadheadtruckingllc.com
# 10   T229522         410648 Ontario Ltd        100.00%  miken@woodcockbrothers.com
# 11   T6222829        JE TRANSPORT EXPRESS LLC  100.00%  chuy-santi@hotmail.com
# 12   T6253487        MRIJA INC                 100.00%  glenda.rodriguez@toshiba.com
# 13   T6251946        RAMCO GROUP LLC           100.00%  rovillarreal@aztecamilling.co
# 14   T6225578        RAJPARKASH SINGH          100.00%  chrobinson@freshdelmonte.onmi
# 15   T5324790        Luis And Sons Express LL  100.00%  sserrano@pressed.com
# 16   T6317167        PARKER'S TRANSPORTATION   100.00%  scott.sansom@aam.com
# 17   T6251957        TRIBAL BEAST LLC          100.00%  tfi_receivingappointments@thu
# 18   T6317122        KEYTRANS LLC              100.00%  acelauro@4c.com
# 19   T6317090        TRANSPORT GP LLC          100.00%  pompanocsr@fidelislogistics.c
# 20   T6245935        GIBCO MOTOR EXPRESS LLC   100.00%  kate82873@gmail.com
# ================================================================================
#       carrier_code                               carrier_name  \
# 0         T6018513                         SKY HIGH TRANS INC
# 1         T2750821                     MOUNTAIN EXPRESS, INC.
# 2         T5323447               INPAX SHIPPING SOLUTIONS INC
# 3         T6000602                        URBAN LOGISTICS LLC
# 4         T6106054                   DOUBLE H CONTRACTORS INC
# ...            ...                                        ...
# 10387     T4371944                           Xela Express Inc
# 10388         T691                  ASCEND TRANSPORTATION LLC
# 10389     T6052965                         Roelcainc SA de CV
# 10390     T5166447                        Orozco Trucking Inc
# 10391     T5002636  Transportes Rivera Gonzalez, S.A. de C.V.
#
#                                       non_chr_recipients  \
# 0                         [hersheysalty@uberfreight.com]
# 1                               [amyw@stoltzfusfeed.com]
# 2                                 [rmckie@shipinpax.com]
# 3                         [urban.logisticsllc@gmail.com]
# 4                               [tammy.jones@kohler.com]
# ...                                                  ...
# 10387  [rebecca.smith@sensiaglobal.com, nsmith@sensia...
# 10388  [robin.derouchie@hdt-ca.com, hector.hernandez@...
# 10389  [rgill@alf-inc.com, emquantixlogistics@celanes...
# 10390  [jarrod.slaughter@hp.com, csi@axlelogistics.co...
# 10391  [jcartia@peltonshepherd.com, operations@easyfl...
#
#                                    recipient_percentages  \
# 0                                                [100.0]
# 1                                                [100.0]
# 2                                                [100.0]
# 3                                                [100.0]
# 4                                                [100.0]
# ...                                                  ...
# 10387  [1.16, 1.16, 0.9, 0.77, 0.77, 0.77, 0.65, 0.65...
# 10388  [1.07, 0.86, 0.86, 0.86, 0.86, 0.8, 0.64, 0.64...
# 10389  [0.9, 0.89, 0.83, 0.78, 0.78, 0.77, 0.75, 0.74...
# 10390  [0.75, 0.75, 0.68, 0.68, 0.68, 0.68, 0.68, 0.6...
# 10391  [0.27, 0.23, 0.22, 0.21, 0.17, 0.15, 0.14, 0.1...
#
#        total_non_chr_emails  unique_recipients  top_recipient_pct
# 0                         1                  1             100.00
# 1                         2                  1             100.00
# 2                         2                  1             100.00
# 3                         5                  1             100.00
# 4                         5                  1             100.00
# ...                     ...                ...                ...
# 10387                   775                345               1.16
# 10388                  1866                783               1.07
# 10389                  6659               1795               0.90
# 10390                  2651                746               0.75
# 10391                 25672               8617               0.27
#
# [10392 rows x 7 columns]

# %%
carrier_recipients_sorted.to_csv('/home/azureuser/trackingContextBuilder/trackingContextBuilder/data/processed/carrier_recipient_analysis.csv', index=False)

# %% [markdown]
# Possible ways to expand analysis
#
# For emails that were sent by non CHR people, take the sender of that email and analyze if the sender is from the carrier or the customer.  (Somehow need to determine logic to know if the email is related to the customer or the carrier)

# %% [markdown]
# ### 📊 Enhanced Analysis: Carrier + Partycode Grouping
#
# **What Changed:**
# Both `analyze_carrier_recipients()` and `analyze_external_senders_by_carrier()` functions now group by **carrier_code AND partycode** instead of just carrier_code.
#
# **Why This Matters:**
# - **Different contacts for different customers**: Carriers may use different people to communicate with CHR depending on which customer (partycode) the load is for
# - **Customer-specific relationships**: Some carrier employees may specialize in specific customer accounts
# - **More granular insights**: Instead of seeing overall carrier communication patterns, we can now see patterns at the carrier-customer level
#
# **Example Use Cases:**
# 1. Identify which carrier contact handles tracking for Customer A vs. Customer B
# 2. Detect if carrier responses come from different departments based on customer
# 3. Understand if certain carrier employees specialize in certain customer relationships
# 4. Optimize communication by routing to the right carrier contact based on customer

# %% [markdown]
# ## 6. Analyze External Email Senders by Carrier and Partycode (Reverse Analysis)
#
# Analyze which external email addresses are sending emails for each carrier-partycode combination (i.e., who at the carriers is responding to CHR tracking requests for specific customers).
# This is the reverse of the previous analysis - instead of looking at who CHR contacts at carriers, we look at who from carriers is responding, broken down by customer (partycode).

# %%
def analyze_external_senders_by_carrier(df):
    """
    Analyze external email senders by carrier code and partycode (REVERSE analysis).
    
    For emails where SENDER_IS_CHR = 0 (external senders), this function:
    1. Filters to only external sender emails
    2. Extracts sender email addresses from the SENDER field
    3. Filters to only non-CHR emails (external senders)
    4. Calculates the percentage of emails sent by each external sender by carrier-partycode combination
    
    This shows which external email addresses are responding/sending emails for each carrier,
    broken down by customer (partycode).
    
    Args:
        df: DataFrame with SENDER_IS_CHR, CARRIER_CODE, PARTYCODES_FINAL, and SENDER columns
        
    Returns:
        DataFrame with columns:
        - carrier_code: The carrier code
        - carrier_name: Carrier name
        - partycode: The customer partycode
        - external_senders: Array of external email addresses
        - sender_percentages: Array of percentages (corresponding to external_senders)
        - total_external_emails: Total number of external sender email instances
        - unique_senders: Count of unique external senders
    """
    import re
    from collections import Counter
    
    def extract_non_chr_email(sender_field):
        """Extract non-CHR email address from the SENDER field."""
        if pd.isna(sender_field) or sender_field == '':
            return None
        
        # Extract all email addresses using regex
        email_pattern = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b'
        emails = re.findall(email_pattern, str(sender_field))
        
        # Filter to only non-CHR emails (not ending in @chrobinson.com)
        non_chr_emails = [
            email.lower() for email in emails 
            if not email.lower().endswith('@chrobinson.com')
        ]
        
        # Return the first non-CHR email found (typically only one sender per email)
        return non_chr_emails[0] if non_chr_emails else None
    
    def get_partycode_string(partycodes_final):
        """Convert partycodes_final to a string representation."""
        if pd.isna(partycodes_final):
            return 'NO_PARTYCODE'
        if isinstance(partycodes_final, list):
            if len(partycodes_final) == 0:
                return 'NO_PARTYCODE'
            # Sort and join for consistent representation
            return ','.join(sorted([str(pc) for pc in partycodes_final]))
        return str(partycodes_final)
    
    # Filter to only rows where SENDER_IS_CHR = 0 (external senders)
    df_external_senders = df[df['SENDER_IS_CHR'] == 0].copy()
    
    # Further filter to only rows with carrier_code
    df_with_carrier = df_external_senders[df_external_senders['carrier_code'].notna()].copy()
    
    # Create partycode string column for grouping
    df_with_carrier['partycode_str'] = df_with_carrier['partycodes_final'].apply(get_partycode_string)
    
    print("="*80)
    print("📊 ANALYZING EXTERNAL SENDERS BY CARRIER AND PARTYCODE (REVERSE ANALYSIS)")
    print("="*80)
    print(f"Total emails from external senders: {len(df_external_senders):,}")
    print(f"External sender emails with carrier code: {len(df_with_carrier):,}")
    print(f"Processing external sender email extraction...")
    print("="*80 + "\n")
    
    # Group by carrier_code AND partycode_str and analyze senders
    results = []
    
    for (carrier_code, partycode_str), group in df_with_carrier.groupby(['carrier_code', 'partycode_str']):
        # Get carrier_name (should be the same for all rows in group)
        carrier_name = group['carrier_name'].iloc[0] if 'carrier_name' in group.columns else None
        
        # Count all external sender emails for this carrier-partycode combination
        all_external_senders = []
        
        for _, row in group.iterrows():
            sender_email = extract_non_chr_email(row['SENDER'])
            if sender_email:
                all_external_senders.append(sender_email)
        
        if len(all_external_senders) == 0:
            # No external senders for this carrier-partycode combination
            continue
        
        # Count occurrences of each sender email
        email_counts = Counter(all_external_senders)
        total_emails = len(all_external_senders)
        
        # Sort by count (descending) to get most common senders first
        sorted_emails = sorted(email_counts.items(), key=lambda x: x[1], reverse=True)
        
        # Extract emails and percentages in the same order
        external_senders = [email for email, count in sorted_emails]
        sender_percentages = [
            round((count / total_emails) * 100, 2) 
            for email, count in sorted_emails
        ]
        
        results.append({
            'carrier_code': carrier_code,
            'carrier_name': carrier_name,
            'partycode': partycode_str,
            'external_senders': external_senders,
            'sender_percentages': sender_percentages,
            'total_external_emails': total_emails,
            'unique_senders': len(external_senders)
        })
    
    # Create result dataframe
    result_df = pd.DataFrame(results)
    
    # Sort by total_external_emails descending
    result_df = result_df.sort_values('total_external_emails', ascending=False).reset_index(drop=True)
    
    print("\n" + "="*80)
    print("📈 REVERSE ANALYSIS SUMMARY")
    print("="*80)
    print(f"Carrier-Partycode combinations with external senders: {len(result_df):,}")
    print(f"Total external sender email instances analyzed: {result_df['total_external_emails'].sum():,}")
    print(f"\nTop 5 carrier-partycode combinations by external sender email volume:")
    for i, row in result_df.head().iterrows():
        carrier_display = f"{row['carrier_code']}"
        if pd.notna(row.get('carrier_name')):
            carrier_display += f" ({row['carrier_name']})"
        partycode_display = f" - Partycode: {row['partycode']}"
        print(f"  {i+1}. {carrier_display}{partycode_display}: {row['total_external_emails']:,} emails from {row['unique_senders']} unique external senders")
    print("="*80)
    
    return result_df

print("✅ External sender analysis function created: analyze_external_senders_by_carrier()")
# Out:
# ✅ External sender analysis function created: analyze_external_senders_by_carrier()

# %%
# Analyze external senders by carrier and partycode (for emails sent TO CHR by external people)
external_senders_by_carrier_df = analyze_external_senders_by_carrier(df_final_filtered)

print(f"\n✅ External sender analysis complete!")
print(f"\nResult dataframe columns:")
print(f"  - carrier_code: Carrier identifier")
print(f"  - carrier_name: Carrier name")
print(f"  - partycode: Customer partycode(s)")
print(f"  - external_senders: Array of external email addresses (sorted by frequency)")
print(f"  - sender_percentages: Percentage of emails from each sender (same order)")
print(f"  - total_external_emails: Total number of external sender email instances")
print(f"  - unique_senders: Count of unique external senders")

external_senders_by_carrier_df.head()
# Out:
# ================================================================================
# 📊 ANALYZING EXTERNAL SENDERS BY CARRIER (REVERSE ANALYSIS)
# ================================================================================
# Total emails from external senders: 361,018
# External sender emails with carrier code: 219,798
# Processing external sender email extraction...
# ================================================================================
#
#
# ================================================================================
# 📈 REVERSE ANALYSIS SUMMARY
# ================================================================================
# Carriers with external senders: 12,610
# Total external sender email instances analyzed: 219,798
#
# Top 5 carriers by external sender email volume:
#   1. T5002636 (Transportes Rivera Gonzalez, S.A. de C.V.): 7,993 emails from 3601 unique external senders
#   2. T6052965 (Roelcainc SA de CV): 2,633 emails from 1016 unique external senders
#   3. T2081243 (ROBERT L GAST INC): 2,426 emails from 462 unique external senders
#   4. T6311362 (TIMEIT LOGISTICS LLC): 2,359 emails from 432 unique external senders
#   5. T6247083 (Power+ (PAVEWAY EXPRESS LTD. CO.)): 2,094 emails from 501 unique external senders
# ================================================================================
#
# ✅ External sender analysis complete!
#
# Result dataframe columns:
#   - carrier_code: Carrier identifier
#   - carrier_name: Carrier name
#   - external_senders: Array of external email addresses (sorted by frequency)
#   - sender_percentages: Percentage of emails from each sender (same order)
#   - total_external_emails: Total number of external sender email instances
#   - unique_senders: Count of unique external senders
#
# ================================================================================
# 📈 REVERSE ANALYSIS SUMMARY
# ================================================================================
# Carriers with external senders: 12,610
# Total external sender email instances analyzed: 219,798
#
# Top 5 carriers by external sender email volume:
#   1. T5002636 (Transportes Rivera Gonzalez, S.A. de C.V.): 7,993 emails from 3601 unique external senders
#   2. T6052965 (Roelcainc SA de CV): 2,633 emails from 1016 unique external senders
#   3. T2081243 (ROBERT L GAST INC): 2,426 emails from 462 unique external senders
#   4. T6311362 (TIMEIT LOGISTICS LLC): 2,359 emails from 432 unique external senders
#   5. T6247083 (Power+ (PAVEWAY EXPRESS LTD. CO.)): 2,094 emails from 501 unique external senders
# ================================================================================
#
# ✅ External sender analysis complete!
#
# Result dataframe columns:
#   - carrier_code: Carrier identifier
#   - carrier_name: Carrier name
#   - external_senders: Array of external email addresses (sorted by frequency)
#   - sender_percentages: Percentage of emails from each sender (same order)
#   - total_external_emails: Total number of external sender email instances
#   - unique_senders: Count of unique external senders
#   carrier_code                               carrier_name  \
# 0     T5002636  Transportes Rivera Gonzalez, S.A. de C.V.
# 1     T6052965                         Roelcainc SA de CV
# 2     T2081243                          ROBERT L GAST INC
# 3     T6311362                       TIMEIT LOGISTICS LLC
# 4     T6247083          Power+ (PAVEWAY EXPRESS LTD. CO.)
#
#                                     external_senders  \
# 0  [diana.vara@doleintl.com, sergio.sanchez@dolei...
# 1  [celanesemorris@quantixscs.com, emquantixlogis...
# 2  [chrtracking@superegoholding.net, dispatch@rob...
# 3  [team9@timeitlogisticsllc.com, team1@timeitlog...
# 4  [niagarabottling_osc@mailph.custhelp.com, kayl...
#
#                                   sender_percentages  total_external_emails  \
# 0  [1.31, 0.58, 0.55, 0.5, 0.46, 0.39, 0.38, 0.33...                   7993
# 1  [1.86, 1.33, 1.29, 0.99, 0.99, 0.95, 0.8, 0.8,...                   2633
# 2  [6.64, 6.47, 4.45, 2.68, 2.35, 2.35, 1.77, 1.6...                   2426
# 3  [11.74, 9.45, 8.69, 8.27, 5.85, 5.0, 3.09, 1.4...                   2359
# 4  [44.7, 2.1, 1.96, 1.38, 1.29, 0.76, 0.62, 0.53...                   2094
#
#    unique_senders
# 0            3601
# 1            1016
# 2             462
# 3             432
# 4             501

# %% [markdown]
# ### Example: View Top External Senders for a Specific Carrier-Partycode Combination
#
# Let's examine which external email addresses send the most emails for one carrier-partycode combination.

# %%
# Example: View details for the carrier with the most external sender emails
if len(external_senders_by_carrier_df) > 0:
    top_carrier = external_senders_by_carrier_df.iloc[0]
    
    print("="*80)
    carrier_display = f"📧 CARRIER: {top_carrier['carrier_code']}"
    if pd.notna(top_carrier.get('carrier_name')):
        carrier_display += f" ({top_carrier['carrier_name']})"
    carrier_display += f" | PARTYCODE: {top_carrier['partycode']}"
    print(carrier_display)
    print("="*80)
    print(f"Total external sender emails: {top_carrier['total_external_emails']:,}")
    print(f"Unique external senders: {top_carrier['unique_senders']}")
    print(f"\nTop 10 External Senders (sorted by percentage):")
    print("-"*80)
    
    for i, (email, pct) in enumerate(zip(
        top_carrier['external_senders'][:10], 
        top_carrier['sender_percentages'][:10]
    ), 1):
        print(f"{i:2d}. {email:50s} {pct:6.2f}%")
    
    print("="*80)
else:
    print("No carriers with external senders found.")
# Out:
# ================================================================================
# 📧 CARRIER: T5002636 (Transportes Rivera Gonzalez, S.A. de C.V.)
# ================================================================================
# Total external sender emails: 7,993
# Unique external senders: 3601
#
# Top 10 External Senders (sorted by percentage):
# --------------------------------------------------------------------------------
#  1. diana.vara@doleintl.com                              1.31%
#  2. sergio.sanchez@doleintl.com                          0.58%
#  3. joym@src.us                                          0.55%
#  4. alondra@valera.com.mx                                0.50%
#  5. sarah.delacruz@vinmar.com                            0.46%
#  6. jcartia@peltonshepherd.com                           0.39%
#  7. sarah@fiberdirectllc.com                             0.38%
#  8. mschneider@phinia.com                                0.33%
#  9. cheryl.williams@emrgroup.com                         0.31%
# 10. team4@eglusainc.com                                  0.30%
# ================================================================================

# %% [markdown]
# ### Identify Carriers with High Sender Concentration
#
# Sort carriers by the percentage of emails coming from their top external sender to find carriers that have most emails sent by a single person.

# %%
# Sort carriers by the percentage coming from their top external sender
# This shows carriers with high email concentration from a single external sender

external_senders_sorted = external_senders_by_carrier_df.copy()

# Extract the first percentage (top sender percentage) for sorting
external_senders_sorted['top_sender_pct'] = external_senders_sorted['sender_percentages'].apply(
    lambda x: x[0] if isinstance(x, list) and len(x) > 0 else 0
)

# Sort by top sender percentage descending
external_senders_sorted = external_senders_sorted.sort_values('top_sender_pct', ascending=False).reset_index(drop=True)

print("="*80)
print("📊 CARRIERS SORTED BY EMAIL CONCENTRATION FROM TOP EXTERNAL SENDER")
print("="*80)
print(f"Total carriers analyzed: {len(external_senders_sorted):,}\n")
print("Top 20 carriers with highest concentration from single external sender:")
print("-"*80)
print(f"{'#':<4} {'Carrier':<15} {'Carrier Name':<25} {'Top %':<8} {'Top External Sender Email':<30}")
print("-"*80)

for i, row in external_senders_sorted.head(20).iterrows():
    carrier = str(row['carrier_code'])[:14]  # Truncate if too long
    carrier_name = str(row.get('carrier_name', ''))[:24] if pd.notna(row.get('carrier_name')) else ''
    top_pct = row['top_sender_pct']
    top_email = row['external_senders'][0] if len(row['external_senders']) > 0 else 'N/A'
    top_email_display = top_email[:29] if len(top_email) > 29 else top_email
    
    print(f"{i+1:<4} {carrier:<15} {carrier_name:<25} {top_pct:>6.2f}%  {top_email_display}")

print("="*80)

# Display the full dataframe sorted
external_senders_sorted
# Out:
# ================================================================================
# 📊 CARRIERS SORTED BY EMAIL CONCENTRATION FROM TOP EXTERNAL SENDER
# ================================================================================
# Total carriers analyzed: 12,610
#
# Top 20 carriers with highest concentration from single external sender:
# --------------------------------------------------------------------------------
# #    Carrier         Carrier Name              Top %    Top External Sender Email
# --------------------------------------------------------------------------------
# 1    T5255316        All Star Logistics Inc    100.00%  cswcaledoniaappts@csw-wi.com
# 2    T6057920        CJ TRANSPORTATION LLC     100.00%  gary.trimble@rxo.com
# 3    T6066075        T & M TRANSPORT LLC       100.00%  canderson@harvesthill.com
# 4    T6281567        VINJAX TRUCKING LLC       100.00%  brenda@wprpwholesalepalletrac
# 5    T2557724        Surface Transport Servic  100.00%  info@surfacetransport.ca
# 6    T4736066        ARM TRUCKING INC          100.00%  armtruckinginc@gmail.com
# 7    T5339990        Dhami Transport Inc       100.00%  nhs-thubservicewest@us.nestle
# 8    T6062134        MAMA TRANSPORTATION LLC   100.00%  cristena@ezporttransportation
# 9    T5189229        INTERLOAD TRUCK SERVICE   100.00%  niagarabottling_osc@mailph.cu
# 10   T4856854        ALPHA EXPRESS LTD         100.00%  praguedispatch1@gmail.com
# 11   T6058094        RD TRUCKING INC           100.00%  collections@trilogy.money
# 12   T4823358        Unlimited Cargo Transpor  100.00%  nicholas.meisner@emerson.com
# 13   T6108481        IND TRANSPORT LLC         100.00%  indtruckingllc1@gmail.com
# 14   T6171320        2568696 ONTARIO INC       100.00%  dispatch@ingersolltransport.c
# 15   T6108969        AB CARRIER LLC            100.00%  abcarrierllc@gmail.com
# 16   T1182504        I-55 LOGISTICS LLC        100.00%  jaked@i55logistics.com
# 17   T6058173        ITRUCKING SOLUTIONS INC   100.00%  gpani@itruckingsolutions.com
# 18   T6058645        CR IDAHO EXPORT LLC       100.00%  dispatch.trips@gmail.com
# 19   T5341257        FOGO TRANSPORT LLC        100.00%  tracking@fjunitedllc.com
# 20   T6058908        JERRY LINCOLN             100.00%  karman1971@hotmail.com
# ================================================================================
#       carrier_code                               carrier_name  \
# 0         T5255316                     All Star Logistics Inc
# 1         T6057920                      CJ TRANSPORTATION LLC
# 2         T6066075                        T & M TRANSPORT LLC
# 3         T6281567                        VINJAX TRUCKING LLC
# 4         T2557724            Surface Transport Services Inc.
# ...            ...                                        ...
# 12605     T5317712               Great Pacific Logistics Inc.
# 12606      T134361                           R H Crawford Inc
# 12607         T691                  ASCEND TRANSPORTATION LLC
# 12608     T6052965                         Roelcainc SA de CV
# 12609     T5002636  Transportes Rivera Gonzalez, S.A. de C.V.
#
#                                         external_senders  \
# 0                         [cswcaledoniaappts@csw-wi.com]
# 1                                 [gary.trimble@rxo.com]
# 2                            [canderson@harvesthill.com]
# 3                   [brenda@wprpwholesalepalletrack.com]
# 4                             [info@surfacetransport.ca]
# ...                                                  ...
# 12605  [dispatch@gillsontrucking.net, costcottr.im@pg...
# 12606  [dispatch.support@munisatrans.com, cs@unisco.c...
# 12607  [deliveryappt@sinotechline.com, dbrossard@asce...
# 12608  [celanesemorris@quantixscs.com, emquantixlogis...
# 12609  [diana.vara@doleintl.com, sergio.sanchez@dolei...
#
#                                       sender_percentages  \
# 0                                                [100.0]
# 1                                                [100.0]
# 2                                                [100.0]
# 3                                                [100.0]
# 4                                                [100.0]
# ...                                                  ...
# 12605  [3.49, 2.85, 2.22, 1.74, 1.58, 1.27, 1.11, 0.9...
# 12606  [2.17, 2.08, 1.7, 1.61, 1.51, 1.32, 1.32, 1.23...
# 12607  [1.99, 1.42, 1.33, 0.95, 0.95, 0.85, 0.85, 0.7...
# 12608  [1.86, 1.33, 1.29, 0.99, 0.99, 0.95, 0.8, 0.8,...
# 12609  [1.31, 0.58, 0.55, 0.5, 0.46, 0.39, 0.38, 0.33...
#
#        total_external_emails  unique_senders  top_sender_pct
# 0                          1               1          100.00
# 1                          2               1          100.00
# 2                          2               1          100.00
# 3                          7               1          100.00
# 4                          7               1          100.00
# ...                      ...             ...             ...
# 12605                    631             320            3.49
# 12606                   1058             437            2.17
# 12607                   1056             498            1.99
# 12608                   2633            1016            1.86
# 12609                   7993            3601            1.31
#
# [12610 rows x 7 columns]

# %%
external_senders_sorted.to_csv('/home/azureuser/trackingContextBuilder/trackingContextBuilder/data/processed/external_senders_by_carrier_analysis.csv', index=False)

# %% [markdown]
# ### Summary: Comparison of Both Analyses
#
# **Analysis 1 - CHR → Carrier Recipients** (`carrier_recipients_sorted`):
# - Analyzes emails where SENDER_IS_CHR = 1 (CHR people sending)
# - Shows which external (non-CHR) email addresses CHR sends tracking requests to
# - **Grouped by carrier_code AND partycode** to show different contacts for different customers
# - Useful for understanding who at the carriers CHR is contacting for each customer
#
# **Analysis 2 - External Senders → CHR** (`external_senders_sorted`):
# - Analyzes emails where SENDER_IS_CHR = 0 (external people sending)
# - Shows which external email addresses are sending emails (by carrier-partycode combination)
# - **Grouped by carrier_code AND partycode** to show different responders for different customers
# - Useful for understanding who at the carriers is responding to CHR tracking requests for each customer
#
# **Key Insight:**
# By grouping by both carrier_code and partycode, we can now see:
# - Whether carriers use different contacts for different customers
# - Whether different carrier employees respond depending on the customer
# - Customer-specific communication patterns and relationships
#
# Both analyses provide:
# - Same output format (carrier_code, carrier_name, partycode, email addresses array, percentages, totals)
# - Sorted by email concentration to identify single points of contact
# - Distribution analysis to see email spread across different senders/recipients
# - Customer-level granularity for more targeted insights
